# %%
import tensorflow as tf
import xgboost as xgb
import pandas as pd
import functools
import time
from tqdm import tqdm
tqdm.pandas()
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, roc_auc_score, \
    auc, average_precision_score, pairwise_distances
import scikitplot as skplt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from xgb_hyper import objective
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import pickle
import dill
from functools import partial
from sklearn.model_selection import train_test_split
from rdkit import Chem
from rdkit.Chem import DataStructs, Descriptors
from rdkit.Chem.AllChem import GetMorganFingerprintAsBitVect
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
import xgboost as xgb
# Out:
# C:\Users\tomas\miniconda3\envs\binding\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\tomas\miniconda3\envs\binding\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\tomas\miniconda3\envs\binding\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\tomas\miniconda3\envs\binding\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\tomas\miniconda3\envs\binding\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\tomas\miniconda3\envs\binding\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config = config)
print("The following GPU devices ara available: %s"%tf.test.gpu_device_name())
# Out:
# The following GPU devices ara available: /device:GPU:0

# %%
def calculate_metrics(y_true, y_pred, plots=False):
    assert isinstance(y_true, np.ndarray), 'y_true should be np.array'
    assert len(y_true.shape) == len(y_pred.shape) == 1, 'y_true or y_pred shapes are not 1 (probably not squeezed)'
    y_pred_bin = y_pred > 0.5

    cf = confusion_matrix(y_true, y_pred_bin)
    tn, fp, fn, tp = cf.ravel()

    metrics = {
        'roc_auc': roc_auc_score(y_true, y_pred),
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'tp': tp,
        'map': average_precision_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred_bin),
        'recall': recall_score(y_true, y_pred_bin),
        'accuracy': accuracy_score(y_true, y_pred_bin),
    }

    if plots:
        print('predictions histogram')
        plt.figure()
        plt.hist(y_pred, bins=int(len(y_pred) / 3))
        plt.show()

        print('confusion matrix')
        plt.figure()
        group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
        group_counts = ['{0:0.0f}'.format(value) for value in
                        cf.flatten()]
        group_percentages = ['{0:.2%}'.format(value) for value in
                             cf.flatten() / np.sum(cf)]
        labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
                  zip(group_names, group_counts, group_percentages)]
        labels = np.asarray(labels).reshape(2, 2)
        sns.heatmap(cf, annot=labels, fmt='', cmap='Blues')
        plt.show()

        print('roc curve')
        random_probs = [0 for _ in range(len(y_true))]
        auc = roc_auc_score(y_true, y_pred)
        print('Logistic: ROC AUC=%.3f' % (auc))
        ns_fpr, ns_tpr, _ = roc_curve(y_true, random_probs)
        lr_fpr, lr_tpr, _ = roc_curve(y_true, y_pred)
        plt.plot(ns_fpr, ns_tpr, linestyle='--', label='random')
        plt.plot(lr_fpr, lr_tpr, marker='.')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend()
        plt.show()

    return metrics

# %%
target_1 = 'pi3k'
base_path_1 = f'C:/Users/tomas/Documents/GitHub/kinase_binding'

data_fpath_1 = base_path_1+f'/data/{target_1}/data.csv'
df_p38=pd.read_csv(data_fpath_1).set_index('biolab_index')

with open(base_path_1+f'/data/{target_1}/train_val_folds.pkl', "rb") as in_f:
    train_val_folds_p38 = dill.load(in_f)

with open(base_path_1+f'/data/{target_1}/train_test_folds.pkl', "rb") as in_f:
    train_test_folds_p38 = dill.load(in_f)
    
target_2 = 'akt1'
base_path_2 = f'C:/Users/tomas/Documents/GitHub/kinase_binding'

data_fpath_2 = base_path_2+f'/data/{target_2}/data.csv'
df_akt1 = pd.read_csv(data_fpath_2).set_index('biolab_index')

with open(base_path_2+f'/data/{target_2}/train_val_folds.pkl', "rb") as in_f:
    train_val_folds_akt1 = dill.load(in_f)
with open(base_path_2+f'/data/{target_2}/train_test_folds.pkl', "rb") as in_f:
    train_test_folds_akt1 = dill.load(in_f)
    
target_3 = 'pi3k'
base_path_3 = f'C:/Users/tomas/Documents/GitHub/kinase_binding'

data_fpath_3 = base_path_3+f'/data/{target_3}/data.csv'
df_pi3k = pd.read_csv(data_fpath_3).set_index('biolab_index')

with open(base_path_3+f'/data/{target_3}/train_val_folds.pkl', "rb") as in_f:
    train_val_folds_pi3k = dill.load(in_f)
with open(base_path_3+f'/data/{target_3}/train_test_folds.pkl', "rb") as in_f:
    train_test_folds_pi3k = dill.load(in_f)

# %%
#Evaluation Splits (our test set)
training_p38 = df_p38.loc[train_test_folds_p38[0]]
validation_p38 = df_p38.loc[train_test_folds_p38[1]]


training_akt1 = df_akt1.loc[train_test_folds_akt1[0]]
validation_akt1 = df_akt1.loc[train_test_folds_akt1[1]]
               

training_pi3k = df_pi3k.loc[train_test_folds_pi3k[0]]
validation_pi3k = df_pi3k.loc[train_test_folds_pi3k[1]]

# %%
#AVE Bias splits (test) only p38
ave_p38_train = pd.read_csv('data/p38/split_aveb/train_all.csv', index_col=0)
ave_p38_val = pd.read_csv('data/p38/split_aveb/test.csv', index_col = 0)
print(len(ave_p38_train),len(ave_p38_val))
# Out:
# 3186 371

# %%
#Random splits with sklearn (on our test set)
df_p38 = df_p38.reset_index(drop=True)
X_train_p38, X_val_p38, Y_train_p38, Y_val_p38 = train_test_split(df_p38.rdkit,
                                                                  df_p38.Binary,
                                                                  test_size = 0.15,
                                                                  train_size = 0.85,
                                                                  shuffle = True)
X_train_p38 = pd.DataFrame(X_train_p38)
X_val_p38 = pd.DataFrame(X_val_p38)
print(len(X_train_p38),len(X_val_p38))
# Out:
# 3190 564

# %%
df_akt1 = df_akt1.reset_index(drop=True)
X_train_akt1, X_val_akt1, Y_train_akt1, Y_val_akt1 = train_test_split(df_akt1.rdkit,
                                                                     df_akt1.Binary,
                                                                     test_size = 0.15,
                                                                     train_size = 0.85,
                                                                     shuffle = True)
X_train_akt1 = pd.DataFrame(X_train_akt1)
X_val_akt1 = pd.DataFrame(X_val_akt1)
print(len(X_train_akt1),len(X_val_akt1))
# Out:
# 1819 321

# %%
df_pi3k = df_pi3k.reset_index(drop=True)
X_train_pi3k, X_val_pi3k, Y_train_pi3k, Y_val_pi3k = train_test_split(df_pi3k.rdkit,
                                                                      df_pi3k.Binary,
                                                                      test_size = 0.15,
                                                                      train_size = 0.85,
                                                                      shuffle = True)
X_train_pi3k = pd.DataFrame(X_train_pi3k)
X_val_pi3k = pd.DataFrame(X_val_pi3k)
print(len(X_train_pi3k),len(X_val_pi3k))
# Out:
# 3190 564

# %%
# defining the space
fspace = {
    'colsample_bylevel' : hp.uniform('colsample_bylevel', 0.1, 1), #+
    'colsample_bytree' : hp.uniform('colsample_bytree', 0.1, 1), #+
    'gamma' : hp.uniform('gamma', 0.1, 1), #+
    'learning_rate' : hp.uniform('learning_rate', 0.1, 1),
    'max_delta_step' : hp.quniform('max_delta_step',1,10,1),
    'max_depth' : hp.quniform('max_depth',6, 12, 1),
    'min_child_weight' : hp.quniform('min_child_weight',10 ,500 ,5),
    'reg_alpha' : hp.uniform('reg_alpha',0.1,100),
    'reg_lambda' : hp.uniform('reg_lambda',0.1,100),
    'subsample' : hp.uniform('subsample',0.1,1.0),
    'max_bin' : hp.quniform('max_bin',16,256,16)
    # add sampling method,max bin,predicto,monotone_constraints,interaction_constraints,single_precision_histogram
}

# %%
fmin_objective = partial(objective, train_sets = training_p38, val_sets = validation_p38)

# %%
def run_trials():

    trials_step = 0  # how many additional trials to do after loading saved trials. 1 = save after iteration
    max_trials = 1  # initial max_trials. put something small to not have to wait

    
    try:  # try to load an already saved trials object, and increase the max
        trials = pickle.load(open("xgboost.hyperopt", "rb"))
        print("Found saved Trials! Loading...")
        max_trials = len(trials.trials) + trials_step
        print("Rerunning from {} trials to {} (+{}) trials".format(len(trials.trials), max_trials, trials_step))
    except:  # create a new trials object and start searching
        trials = Trials()

    best = fmin(fn = fmin_objective, space = fspace, algo=tpe.suggest, max_evals=max_trials, trials=trials)

    print("Best:", best)
    
    # save the trials object
    with open("xgboost.hyperopt", "wb") as f:
        pickle.dump(trials, f)
    return(trials)

# %%
trials = run_trials()
# Out:
# Found saved Trials! Loading...
# Rerunning from 510 trials to 510 (+0) trials
# 100%|████████████████████████████████████████████████████████████████████████| 510/510 [00:00<?, ?trial/s, best loss=?]
# Best: {'colsample_bylevel': 0.5612301667238877, 'colsample_bytree': 0.788688363076523, 'gamma': 0.35376030016117566, 'learning_rate': 0.4023692255888918, 'max_bin': 16.0, 'max_delta_step': 3.0, 'max_depth': 8.0, 'min_child_weight': 70.0, 'reg_alpha': 0.15030685758880047, 'reg_lambda': 15.311721955443915, 'subsample': 0.8303923929525608}

# %%
best_loss = trials.trials[0]['result']['loss']
for i in range(1,len(trials.trials)):
    if (trials.trials[i]['result']['loss'] <=  best_loss):
        best_loss = trials.trials[i]['result']['loss']
        index = i

    
best_params = trials.trials[index]['misc']['vals']
hyper_params = {
        "colsample_bylevel" : best_params['colsample_bylevel'][0],
        "colsample_bytree" : best_params['colsample_bytree'][0],
        "gamma" : best_params['gamma'][0],
        "eta" : best_params['learning_rate'][0],
        "max_delta_step" : int(best_params['max_delta_step'][0]),
        "max_depth" : int(best_params['max_depth'][0]),
        "min_child_weight" : int(best_params['min_child_weight'][0]),
        "alpha" : best_params['reg_alpha'][0],
        "lambda" : best_params['reg_lambda'][0],
        "subsample" : best_params['subsample'][0],
        "eval_metric":'auc',
        "objective":'binary:logistic',
        "booster":'gbtree',
        "tree_method" : 'gpu_hist',
        "single_precision_histogram" : True
}
from xgb_hyper import XGB_hyper
class_xgb = XGB_hyper(hyper_params)

# %%
train_list_p38 = [training_p38, ave_p38_train, X_train_p38]
val_list_p38 = [validation_p38, ave_p38_val, X_val_p38]

train_list_akt1 = [training_akt1, X_train_akt1]
val_list_akt1 = [validation_akt1, X_val_akt1]

train_list_pi3k = [training_pi3k, X_train_pi3k]
val_list_pi3k = [validation_pi3k, X_val_pi3k]

# %%
eval_p38 = {}
for i in range(len(train_list_p38)):
    if i == 2:
        smi = train_list_p38[i].rdkit
        mols = [Chem.MolFromSmiles(smi) for smi in smi]
        ECFP = [AllChem.GetMorganFingerprintAsBitVect(x,2,nBits=1024) for x in mols]
        a = np.array(ECFP)
        ECFP_smiles = a.astype(np.float32)
        train_labels = Y_train_p38
        dmatrix_train = xgb.DMatrix(data = ECFP_smiles,label = train_labels)
        
        smi = val_list_p38[i].rdkit
        mols = [Chem.MolFromSmiles(smi) for smi in smi]
        ECFP = [AllChem.GetMorganFingerprintAsBitVect(x,2,nBits=1024) for x in mols]
        a = np.array(ECFP)
        ECFP_smiles = a.astype(np.float32)
        val_labels = Y_val_p38
        dmatrix_val = xgb.DMatrix(data = ECFP_smiles,label = val_labels)
        del smi,mols,ECFP,a,ECFP_smiles
        
        evalist = [(dmatrix_val,'eval'),(dmatrix_train,'train')]
        model = class_xgb.build_model(dmatrix_train,evalist,True,300)
    else:
        dmatrix_train,train_labels = class_xgb.to_xgb_input(train_list_p38[i])
        dmatrix_val,val_labels = class_xgb.to_xgb_input(val_list_p38[i])
        evalist = [(dmatrix_val,'eval'),(dmatrix_train,'train')]
        model = class_xgb.build_model(dmatrix_train,evalist,True,300)
    
    y_pred_val = model.predict(dmatrix_val)
    if i == 0:
        eval_p38['Test'] = calculate_metrics(np.array(val_labels),y_pred_val)
    elif i == 1:
        eval_p38['Ave'] = calculate_metrics(np.array(val_labels),y_pred_val)
    elif i == 2:
        eval_p38['Random'] = calculate_metrics(np.array(val_labels),y_pred_val)
# Out:
# [0]	eval-auc:0.72200	train-auc:0.70592
# [1]	eval-auc:0.68301	train-auc:0.74260
# [2]	eval-auc:0.69628	train-auc:0.76914
# [3]	eval-auc:0.69529	train-auc:0.78318
# [4]	eval-auc:0.73879	train-auc:0.78736
# [5]	eval-auc:0.71432	train-auc:0.80538
# [6]	eval-auc:0.72304	train-auc:0.80939
# [7]	eval-auc:0.72648	train-auc:0.81340
# [8]	eval-auc:0.74481	train-auc:0.81878
# [9]	eval-auc:0.75756	train-auc:0.82219
# [10]	eval-auc:0.76321	train-auc:0.82756
# [11]	eval-auc:0.77043	train-auc:0.83228
# [12]	eval-auc:0.76563	train-auc:0.83384
# [13]	eval-auc:0.75301	train-auc:0.83662
# [14]	eval-auc:0.76732	train-auc:0.83935
# [15]	eval-auc:0.77700	train-auc:0.84346
# [16]	eval-auc:0.77670	train-auc:0.84503
# [17]	eval-auc:0.77566	train-auc:0.84694
# [18]	eval-auc:0.77779	train-auc:0.85008
# [19]	eval-auc:0.78445	train-auc:0.85382
# [20]	eval-auc:0.78817	train-auc:0.85549
# [21]	eval-auc:0.79499	train-auc:0.85830
# [22]	eval-auc:0.79734	train-auc:0.85938
# [23]	eval-auc:0.79707	train-auc:0.86167
# [24]	eval-auc:0.79722	train-auc:0.86485
# [25]	eval-auc:0.80383	train-auc:0.86606
# [26]	eval-auc:0.80507	train-auc:0.86658
# [27]	eval-auc:0.80554	train-auc:0.86771
# [28]	eval-auc:0.80808	train-auc:0.86815
# [29]	eval-auc:0.80585	train-auc:0.86891
# [30]	eval-auc:0.80629	train-auc:0.87005
# [31]	eval-auc:0.81670	train-auc:0.87105
# [32]	eval-auc:0.81877	train-auc:0.87167
# [33]	eval-auc:0.81482	train-auc:0.87357
# [34]	eval-auc:0.81565	train-auc:0.87412
# [35]	eval-auc:0.81901	train-auc:0.87522
# [36]	eval-auc:0.81733	train-auc:0.87597
# [37]	eval-auc:0.82067	train-auc:0.87679
# [38]	eval-auc:0.82025	train-auc:0.87769
# [39]	eval-auc:0.81904	train-auc:0.87866
# [40]	eval-auc:0.82318	train-auc:0.87957
# [41]	eval-auc:0.82233	train-auc:0.87995
# [42]	eval-auc:0.82072	train-auc:0.88014
# [43]	eval-auc:0.82340	train-auc:0.88097
# [44]	eval-auc:0.82458	train-auc:0.88148
# [45]	eval-auc:0.82677	train-auc:0.88157
# [46]	eval-auc:0.82731	train-auc:0.88214
# [47]	eval-auc:0.82554	train-auc:0.88249
# [48]	eval-auc:0.82558	train-auc:0.88308
# [49]	eval-auc:0.82035	train-auc:0.88368
# [50]	eval-auc:0.82204	train-auc:0.88418
# [51]	eval-auc:0.82892	train-auc:0.88486
# [52]	eval-auc:0.82485	train-auc:0.88474
# [53]	eval-auc:0.82391	train-auc:0.88545
# [54]	eval-auc:0.82280	train-auc:0.88614
# [55]	eval-auc:0.82494	train-auc:0.88643
# [56]	eval-auc:0.82181	train-auc:0.88677
# [57]	eval-auc:0.82651	train-auc:0.88791
# [58]	eval-auc:0.82575	train-auc:0.88841
# [59]	eval-auc:0.82652	train-auc:0.88873
# [60]	eval-auc:0.82508	train-auc:0.88897
# [61]	eval-auc:0.82582	train-auc:0.89049
# [62]	eval-auc:0.82922	train-auc:0.89159
# [63]	eval-auc:0.82609	train-auc:0.89233
# [64]	eval-auc:0.82849	train-auc:0.89263
# [65]	eval-auc:0.82595	train-auc:0.89321
# [66]	eval-auc:0.82934	train-auc:0.89371
# [67]	eval-auc:0.82584	train-auc:0.89428
# [68]	eval-auc:0.82865	train-auc:0.89450
# [69]	eval-auc:0.82720	train-auc:0.89449
# [70]	eval-auc:0.83075	train-auc:0.89489
# [71]	eval-auc:0.82995	train-auc:0.89517
# [72]	eval-auc:0.83241	train-auc:0.89561
# [73]	eval-auc:0.83249	train-auc:0.89573
# [74]	eval-auc:0.83238	train-auc:0.89582
# [75]	eval-auc:0.83307	train-auc:0.89596
# [76]	eval-auc:0.83368	train-auc:0.89640
# [77]	eval-auc:0.83308	train-auc:0.89634
# [78]	eval-auc:0.83306	train-auc:0.89655
# [79]	eval-auc:0.83490	train-auc:0.89716
# [80]	eval-auc:0.83413	train-auc:0.89751
# [81]	eval-auc:0.83544	train-auc:0.89805
# [82]	eval-auc:0.83613	train-auc:0.89822
# [83]	eval-auc:0.83705	train-auc:0.89859
# [84]	eval-auc:0.83537	train-auc:0.89885
# [85]	eval-auc:0.83428	train-auc:0.89949
# [86]	eval-auc:0.83512	train-auc:0.90024
# [87]	eval-auc:0.83453	train-auc:0.90049
# [88]	eval-auc:0.83428	train-auc:0.90087
# [89]	eval-auc:0.83634	train-auc:0.90098
# [90]	eval-auc:0.83661	train-auc:0.90170
# [91]	eval-auc:0.83458	train-auc:0.90200
# [92]	eval-auc:0.83296	train-auc:0.90206
# [93]	eval-auc:0.83532	train-auc:0.90207
# [94]	eval-auc:0.83264	train-auc:0.90273
# [95]	eval-auc:0.83276	train-auc:0.90303
# [96]	eval-auc:0.83571	train-auc:0.90363
# [97]	eval-auc:0.83689	train-auc:0.90412
# [98]	eval-auc:0.83593	train-auc:0.90431
# [99]	eval-auc:0.83625	train-auc:0.90414
# [100]	eval-auc:0.84069	train-auc:0.90470
# [101]	eval-auc:0.84034	train-auc:0.90505
# [102]	eval-auc:0.83843	train-auc:0.90521
# [103]	eval-auc:0.83918	train-auc:0.90557
# [104]	eval-auc:0.84265	train-auc:0.90567
# [105]	eval-auc:0.84415	train-auc:0.90593
# [106]	eval-auc:0.84384	train-auc:0.90606
# [107]	eval-auc:0.84342	train-auc:0.90635
# [108]	eval-auc:0.84461	train-auc:0.90664
# [109]	eval-auc:0.84495	train-auc:0.90708
# [110]	eval-auc:0.84710	train-auc:0.90729
# [111]	eval-auc:0.84754	train-auc:0.90747
# [112]	eval-auc:0.85002	train-auc:0.90776
# [113]	eval-auc:0.84878	train-auc:0.90773
# [114]	eval-auc:0.84955	train-auc:0.90813
# [115]	eval-auc:0.85145	train-auc:0.90802
# [116]	eval-auc:0.85112	train-auc:0.90822
# [117]	eval-auc:0.85184	train-auc:0.90938
# [118]	eval-auc:0.85120	train-auc:0.90938
# [119]	eval-auc:0.85144	train-auc:0.90948
# [120]	eval-auc:0.84919	train-auc:0.90989
# [121]	eval-auc:0.85118	train-auc:0.91039
# [122]	eval-auc:0.84962	train-auc:0.91019
# [123]	eval-auc:0.85057	train-auc:0.91027
# [124]	eval-auc:0.85076	train-auc:0.91051
# [125]	eval-auc:0.84962	train-auc:0.91084
# [126]	eval-auc:0.85076	train-auc:0.91103
# [127]	eval-auc:0.85177	train-auc:0.91131
# [128]	eval-auc:0.85159	train-auc:0.91159
# [129]	eval-auc:0.85013	train-auc:0.91171
# [130]	eval-auc:0.84867	train-auc:0.91171
# [131]	eval-auc:0.84889	train-auc:0.91212
# [132]	eval-auc:0.84789	train-auc:0.91225
# [133]	eval-auc:0.84836	train-auc:0.91232
# [134]	eval-auc:0.85018	train-auc:0.91251
# [135]	eval-auc:0.84936	train-auc:0.91253
# [136]	eval-auc:0.85008	train-auc:0.91268
# [137]	eval-auc:0.85127	train-auc:0.91307
# [138]	eval-auc:0.85133	train-auc:0.91317
# [139]	eval-auc:0.85111	train-auc:0.91313
# [140]	eval-auc:0.85188	train-auc:0.91304
# [141]	eval-auc:0.85091	train-auc:0.91342
# [142]	eval-auc:0.85309	train-auc:0.91366
# [143]	eval-auc:0.85392	train-auc:0.91378
# [144]	eval-auc:0.85218	train-auc:0.91401
# [145]	eval-auc:0.85196	train-auc:0.91391
# [146]	eval-auc:0.85372	train-auc:0.91466
# [147]	eval-auc:0.85367	train-auc:0.91479
# [148]	eval-auc:0.85375	train-auc:0.91514
# [149]	eval-auc:0.85380	train-auc:0.91523
# [150]	eval-auc:0.85174	train-auc:0.91576
# [151]	eval-auc:0.85290	train-auc:0.91615
# [152]	eval-auc:0.85176	train-auc:0.91627
# [153]	eval-auc:0.85250	train-auc:0.91641
# [154]	eval-auc:0.85206	train-auc:0.91680
# [155]	eval-auc:0.85295	train-auc:0.91665
# [156]	eval-auc:0.85493	train-auc:0.91683
# [157]	eval-auc:0.85372	train-auc:0.91701
# [158]	eval-auc:0.85562	train-auc:0.91772
# [159]	eval-auc:0.85607	train-auc:0.91800
# [160]	eval-auc:0.85672	train-auc:0.91828
# [161]	eval-auc:0.85446	train-auc:0.91832
# [162]	eval-auc:0.85297	train-auc:0.91809
# [163]	eval-auc:0.85469	train-auc:0.91824
# [164]	eval-auc:0.85648	train-auc:0.91814
# [165]	eval-auc:0.85573	train-auc:0.91827
# [166]	eval-auc:0.85665	train-auc:0.91857
# [167]	eval-auc:0.85750	train-auc:0.91872
# [168]	eval-auc:0.85573	train-auc:0.91864
# [169]	eval-auc:0.85421	train-auc:0.91881
# [170]	eval-auc:0.85289	train-auc:0.91884
# [171]	eval-auc:0.85417	train-auc:0.91892
# [172]	eval-auc:0.85417	train-auc:0.91895
# [173]	eval-auc:0.85540	train-auc:0.91897
# [174]	eval-auc:0.85808	train-auc:0.91917
# [175]	eval-auc:0.85672	train-auc:0.91929
# [176]	eval-auc:0.85810	train-auc:0.91932
# [177]	eval-auc:0.85880	train-auc:0.91945
# [178]	eval-auc:0.85785	train-auc:0.91960
# [179]	eval-auc:0.85815	train-auc:0.91968
# [180]	eval-auc:0.85788	train-auc:0.91972
# [181]	eval-auc:0.85924	train-auc:0.92022
# [182]	eval-auc:0.85869	train-auc:0.92020
# [183]	eval-auc:0.85884	train-auc:0.92011
# [184]	eval-auc:0.85863	train-auc:0.92029
# [185]	eval-auc:0.85941	train-auc:0.92032
# [186]	eval-auc:0.86189	train-auc:0.92066
# [187]	eval-auc:0.86206	train-auc:0.92063
# [188]	eval-auc:0.86142	train-auc:0.92072
# [189]	eval-auc:0.86153	train-auc:0.92102
# [190]	eval-auc:0.86253	train-auc:0.92105
# [191]	eval-auc:0.86350	train-auc:0.92133
# [192]	eval-auc:0.86033	train-auc:0.92152
# [193]	eval-auc:0.86071	train-auc:0.92179
# [194]	eval-auc:0.85986	train-auc:0.92188
# [195]	eval-auc:0.86154	train-auc:0.92202
# [196]	eval-auc:0.86184	train-auc:0.92204
# [197]	eval-auc:0.86060	train-auc:0.92218
# [198]	eval-auc:0.86120	train-auc:0.92215
# [199]	eval-auc:0.86131	train-auc:0.92221
# [200]	eval-auc:0.86234	train-auc:0.92242
# [201]	eval-auc:0.86399	train-auc:0.92246
# [202]	eval-auc:0.86474	train-auc:0.92248
# [203]	eval-auc:0.86484	train-auc:0.92273
# [204]	eval-auc:0.86407	train-auc:0.92266
# [205]	eval-auc:0.86165	train-auc:0.92294
# [206]	eval-auc:0.86214	train-auc:0.92298
# [207]	eval-auc:0.85964	train-auc:0.92307
# [208]	eval-auc:0.86035	train-auc:0.92327
# [209]	eval-auc:0.86176	train-auc:0.92366
# [210]	eval-auc:0.86229	train-auc:0.92377
# [211]	eval-auc:0.86227	train-auc:0.92380
# [212]	eval-auc:0.86188	train-auc:0.92384
# [213]	eval-auc:0.86092	train-auc:0.92397
# [214]	eval-auc:0.86199	train-auc:0.92414
# [215]	eval-auc:0.86205	train-auc:0.92434
# [216]	eval-auc:0.86132	train-auc:0.92441
# [217]	eval-auc:0.86307	train-auc:0.92464
# [218]	eval-auc:0.86268	train-auc:0.92482
# [219]	eval-auc:0.86197	train-auc:0.92489
# [220]	eval-auc:0.86332	train-auc:0.92493
# [221]	eval-auc:0.86369	train-auc:0.92509
# [222]	eval-auc:0.86287	train-auc:0.92524
# [223]	eval-auc:0.86392	train-auc:0.92541
# [224]	eval-auc:0.86310	train-auc:0.92558
# [225]	eval-auc:0.86375	train-auc:0.92568
# [226]	eval-auc:0.86383	train-auc:0.92548
# [227]	eval-auc:0.86315	train-auc:0.92552
# [228]	eval-auc:0.86394	train-auc:0.92582
# [229]	eval-auc:0.86532	train-auc:0.92588
# [230]	eval-auc:0.86442	train-auc:0.92590
# [231]	eval-auc:0.86401	train-auc:0.92599
# [232]	eval-auc:0.86519	train-auc:0.92619
# [233]	eval-auc:0.86400	train-auc:0.92638
# [234]	eval-auc:0.86351	train-auc:0.92645
# [235]	eval-auc:0.86293	train-auc:0.92660
# [236]	eval-auc:0.86183	train-auc:0.92641
# [237]	eval-auc:0.86356	train-auc:0.92674
# [238]	eval-auc:0.86216	train-auc:0.92668
# [239]	eval-auc:0.86194	train-auc:0.92678
# [240]	eval-auc:0.86083	train-auc:0.92701
# [241]	eval-auc:0.86069	train-auc:0.92711
# [242]	eval-auc:0.86072	train-auc:0.92699
# [243]	eval-auc:0.86176	train-auc:0.92699
# [244]	eval-auc:0.86306	train-auc:0.92736
# [245]	eval-auc:0.86321	train-auc:0.92737
# [246]	eval-auc:0.86274	train-auc:0.92764
# [247]	eval-auc:0.86163	train-auc:0.92786
# [248]	eval-auc:0.86263	train-auc:0.92793
# [249]	eval-auc:0.86419	train-auc:0.92797
# [250]	eval-auc:0.86317	train-auc:0.92800
# [251]	eval-auc:0.86326	train-auc:0.92802
# [252]	eval-auc:0.86246	train-auc:0.92802
# [253]	eval-auc:0.86419	train-auc:0.92815
# [254]	eval-auc:0.86365	train-auc:0.92831
# [255]	eval-auc:0.86585	train-auc:0.92850
# [256]	eval-auc:0.86478	train-auc:0.92868
# [257]	eval-auc:0.86491	train-auc:0.92862
# [258]	eval-auc:0.86547	train-auc:0.92849
# [259]	eval-auc:0.86584	train-auc:0.92862
# [260]	eval-auc:0.86728	train-auc:0.92876
# [261]	eval-auc:0.86696	train-auc:0.92878
# [262]	eval-auc:0.86686	train-auc:0.92889
# [263]	eval-auc:0.86722	train-auc:0.92908
# [264]	eval-auc:0.86756	train-auc:0.92919
# [265]	eval-auc:0.86778	train-auc:0.92929
# [266]	eval-auc:0.86701	train-auc:0.92955
# [267]	eval-auc:0.86582	train-auc:0.92983
# [268]	eval-auc:0.86486	train-auc:0.92974
# [269]	eval-auc:0.86601	train-auc:0.92982
# [270]	eval-auc:0.86613	train-auc:0.92989
# [271]	eval-auc:0.86618	train-auc:0.92993
# [272]	eval-auc:0.86612	train-auc:0.92995
# [273]	eval-auc:0.86794	train-auc:0.93004
# [274]	eval-auc:0.86822	train-auc:0.93025
# [275]	eval-auc:0.86846	train-auc:0.93036
# [276]	eval-auc:0.86817	train-auc:0.93044
# [277]	eval-auc:0.86780	train-auc:0.93059
# [278]	eval-auc:0.86726	train-auc:0.93081
# [279]	eval-auc:0.86711	train-auc:0.93086
# [280]	eval-auc:0.86670	train-auc:0.93095
# [281]	eval-auc:0.86748	train-auc:0.93109
# [282]	eval-auc:0.86808	train-auc:0.93131
# [283]	eval-auc:0.86740	train-auc:0.93130
# [284]	eval-auc:0.86724	train-auc:0.93139
# [285]	eval-auc:0.86752	train-auc:0.93139
# [286]	eval-auc:0.86826	train-auc:0.93154
# [287]	eval-auc:0.86878	train-auc:0.93155
# [288]	eval-auc:0.86893	train-auc:0.93161
# [289]	eval-auc:0.86977	train-auc:0.93171
# [290]	eval-auc:0.87080	train-auc:0.93187
# [291]	eval-auc:0.87155	train-auc:0.93183
# [292]	eval-auc:0.87036	train-auc:0.93183
# [293]	eval-auc:0.87063	train-auc:0.93202
# [294]	eval-auc:0.87047	train-auc:0.93203
# [295]	eval-auc:0.86984	train-auc:0.93205
# [296]	eval-auc:0.86983	train-auc:0.93204
# [297]	eval-auc:0.86953	train-auc:0.93221
# [298]	eval-auc:0.86920	train-auc:0.93246
# [299]	eval-auc:0.86930	train-auc:0.93259
# [0]	eval-auc:0.64934	train-auc:0.70637
# [1]	eval-auc:0.68631	train-auc:0.74123
# [2]	eval-auc:0.71200	train-auc:0.77210
# [3]	eval-auc:0.69925	train-auc:0.78206
# [4]	eval-auc:0.68849	train-auc:0.80541
# [5]	eval-auc:0.69270	train-auc:0.81239
# [6]	eval-auc:0.71152	train-auc:0.81299
# [7]	eval-auc:0.71300	train-auc:0.82176
# [8]	eval-auc:0.71131	train-auc:0.82624
# [9]	eval-auc:0.71511	train-auc:0.83169
# [10]	eval-auc:0.72951	train-auc:0.83334
# [11]	eval-auc:0.72569	train-auc:0.83673
# [12]	eval-auc:0.73616	train-auc:0.84283
# [13]	eval-auc:0.73564	train-auc:0.84662
# [14]	eval-auc:0.74132	train-auc:0.84873
# [15]	eval-auc:0.73778	train-auc:0.85124
# [16]	eval-auc:0.72956	train-auc:0.85425
# [17]	eval-auc:0.73190	train-auc:0.85655
# [18]	eval-auc:0.73747	train-auc:0.85699
# [19]	eval-auc:0.73993	train-auc:0.85937
# [20]	eval-auc:0.74078	train-auc:0.86041
# [21]	eval-auc:0.73768	train-auc:0.86170
# [22]	eval-auc:0.73771	train-auc:0.86313
# [23]	eval-auc:0.74004	train-auc:0.86434
# [24]	eval-auc:0.73905	train-auc:0.86586
# [25]	eval-auc:0.72680	train-auc:0.86706
# [26]	eval-auc:0.72849	train-auc:0.86760
# [27]	eval-auc:0.72940	train-auc:0.86801
# [28]	eval-auc:0.73374	train-auc:0.86963
# [29]	eval-auc:0.73419	train-auc:0.87049
# [30]	eval-auc:0.73403	train-auc:0.87183
# [31]	eval-auc:0.74474	train-auc:0.87292
# [32]	eval-auc:0.74470	train-auc:0.87369
# [33]	eval-auc:0.75190	train-auc:0.87565
# [34]	eval-auc:0.75194	train-auc:0.87564
# [35]	eval-auc:0.74229	train-auc:0.87657
# [36]	eval-auc:0.74556	train-auc:0.87766
# [37]	eval-auc:0.75359	train-auc:0.87831
# [38]	eval-auc:0.75322	train-auc:0.87862
# [39]	eval-auc:0.75125	train-auc:0.87922
# [40]	eval-auc:0.75125	train-auc:0.87995
# [41]	eval-auc:0.75076	train-auc:0.88028
# [42]	eval-auc:0.75009	train-auc:0.88054
# [43]	eval-auc:0.75019	train-auc:0.88196
# [44]	eval-auc:0.74794	train-auc:0.88415
# [45]	eval-auc:0.74692	train-auc:0.88499
# [46]	eval-auc:0.74653	train-auc:0.88556
# [47]	eval-auc:0.74533	train-auc:0.88600
# [48]	eval-auc:0.73935	train-auc:0.88636
# [49]	eval-auc:0.74048	train-auc:0.88670
# [50]	eval-auc:0.74238	train-auc:0.88777
# [51]	eval-auc:0.74396	train-auc:0.88900
# [52]	eval-auc:0.74357	train-auc:0.88916
# [53]	eval-auc:0.74313	train-auc:0.88918
# [54]	eval-auc:0.74525	train-auc:0.88967
# [55]	eval-auc:0.74560	train-auc:0.88988
# [56]	eval-auc:0.74722	train-auc:0.89048
# [57]	eval-auc:0.74468	train-auc:0.89131
# [58]	eval-auc:0.74366	train-auc:0.89169
# [59]	eval-auc:0.74761	train-auc:0.89222
# [60]	eval-auc:0.75018	train-auc:0.89237
# [61]	eval-auc:0.75162	train-auc:0.89236
# [62]	eval-auc:0.75493	train-auc:0.89314
# [63]	eval-auc:0.75831	train-auc:0.89422
# [64]	eval-auc:0.75915	train-auc:0.89462
# [65]	eval-auc:0.75996	train-auc:0.89517
# [66]	eval-auc:0.75586	train-auc:0.89521
# [67]	eval-auc:0.75614	train-auc:0.89546
# [68]	eval-auc:0.75614	train-auc:0.89538
# [69]	eval-auc:0.75400	train-auc:0.89531
# [70]	eval-auc:0.75410	train-auc:0.89558
# [71]	eval-auc:0.75343	train-auc:0.89597
# [72]	eval-auc:0.74365	train-auc:0.89656
# [73]	eval-auc:0.74889	train-auc:0.89767
# [74]	eval-auc:0.74875	train-auc:0.89837
# [75]	eval-auc:0.74301	train-auc:0.89837
# [76]	eval-auc:0.74544	train-auc:0.89900
# [77]	eval-auc:0.74636	train-auc:0.89945
# [78]	eval-auc:0.75255	train-auc:0.89981
# [79]	eval-auc:0.75199	train-auc:0.90067
# [80]	eval-auc:0.75206	train-auc:0.90067
# [81]	eval-auc:0.75650	train-auc:0.90068
# [82]	eval-auc:0.75667	train-auc:0.90085
# [83]	eval-auc:0.75537	train-auc:0.90104
# [84]	eval-auc:0.75379	train-auc:0.90131
# [85]	eval-auc:0.75227	train-auc:0.90161
# [86]	eval-auc:0.75283	train-auc:0.90180
# [87]	eval-auc:0.75291	train-auc:0.90194
# [88]	eval-auc:0.75804	train-auc:0.90207
# [89]	eval-auc:0.75734	train-auc:0.90221
# [90]	eval-auc:0.75755	train-auc:0.90228
# [91]	eval-auc:0.75555	train-auc:0.90224
# [92]	eval-auc:0.75938	train-auc:0.90255
# [93]	eval-auc:0.75896	train-auc:0.90286
# [94]	eval-auc:0.75699	train-auc:0.90329
# [95]	eval-auc:0.75713	train-auc:0.90384
# [96]	eval-auc:0.75711	train-auc:0.90397
# [97]	eval-auc:0.75452	train-auc:0.90412
# [98]	eval-auc:0.75241	train-auc:0.90443
# [99]	eval-auc:0.75562	train-auc:0.90478
# [100]	eval-auc:0.75505	train-auc:0.90468
# [101]	eval-auc:0.75040	train-auc:0.90485
# [102]	eval-auc:0.75343	train-auc:0.90511
# [103]	eval-auc:0.75562	train-auc:0.90545
# [104]	eval-auc:0.75371	train-auc:0.90524
# [105]	eval-auc:0.76132	train-auc:0.90635
# [106]	eval-auc:0.76079	train-auc:0.90677
# [107]	eval-auc:0.76519	train-auc:0.90749
# [108]	eval-auc:0.76512	train-auc:0.90767
# [109]	eval-auc:0.76414	train-auc:0.90805
# [110]	eval-auc:0.76526	train-auc:0.90847
# [111]	eval-auc:0.76811	train-auc:0.90894
# [112]	eval-auc:0.76579	train-auc:0.90913
# [113]	eval-auc:0.76723	train-auc:0.90949
# [114]	eval-auc:0.76519	train-auc:0.90963
# [115]	eval-auc:0.76480	train-auc:0.90962
# [116]	eval-auc:0.76699	train-auc:0.90978
# [117]	eval-auc:0.76833	train-auc:0.91007
# [118]	eval-auc:0.76734	train-auc:0.91006
# [119]	eval-auc:0.76794	train-auc:0.91067
# [120]	eval-auc:0.76973	train-auc:0.91058
# [121]	eval-auc:0.77420	train-auc:0.91065
# [122]	eval-auc:0.77392	train-auc:0.91089
# [123]	eval-auc:0.77491	train-auc:0.91117
# [124]	eval-auc:0.77663	train-auc:0.91134
# [125]	eval-auc:0.77575	train-auc:0.91180
# [126]	eval-auc:0.77501	train-auc:0.91196
# [127]	eval-auc:0.77537	train-auc:0.91205
# [128]	eval-auc:0.77431	train-auc:0.91229
# [129]	eval-auc:0.77301	train-auc:0.91247
# [130]	eval-auc:0.76917	train-auc:0.91285
# [131]	eval-auc:0.76811	train-auc:0.91322
# [132]	eval-auc:0.77086	train-auc:0.91347
# [133]	eval-auc:0.77353	train-auc:0.91351
# [134]	eval-auc:0.77265	train-auc:0.91380
# [135]	eval-auc:0.77163	train-auc:0.91372
# [136]	eval-auc:0.77146	train-auc:0.91368
# [137]	eval-auc:0.76903	train-auc:0.91381
# [138]	eval-auc:0.77009	train-auc:0.91396
# [139]	eval-auc:0.76769	train-auc:0.91411
# [140]	eval-auc:0.76737	train-auc:0.91413
# [141]	eval-auc:0.76776	train-auc:0.91454
# [142]	eval-auc:0.76882	train-auc:0.91470
# [143]	eval-auc:0.76850	train-auc:0.91480
# [144]	eval-auc:0.76885	train-auc:0.91506
# [145]	eval-auc:0.77089	train-auc:0.91507
# [146]	eval-auc:0.76730	train-auc:0.91513
# [147]	eval-auc:0.76910	train-auc:0.91510
# [148]	eval-auc:0.77128	train-auc:0.91552
# [149]	eval-auc:0.77044	train-auc:0.91594
# [150]	eval-auc:0.77350	train-auc:0.91643
# [151]	eval-auc:0.77100	train-auc:0.91651
# [152]	eval-auc:0.76928	train-auc:0.91654
# [153]	eval-auc:0.77033	train-auc:0.91656
# [154]	eval-auc:0.77114	train-auc:0.91687
# [155]	eval-auc:0.76896	train-auc:0.91737
# [156]	eval-auc:0.76706	train-auc:0.91768
# [157]	eval-auc:0.76825	train-auc:0.91751
# [158]	eval-auc:0.77163	train-auc:0.91802
# [159]	eval-auc:0.76970	train-auc:0.91800
# [160]	eval-auc:0.76769	train-auc:0.91829
# [161]	eval-auc:0.76850	train-auc:0.91850
# [162]	eval-auc:0.76773	train-auc:0.91850
# [163]	eval-auc:0.76442	train-auc:0.91866
# [164]	eval-auc:0.76326	train-auc:0.91882
# [165]	eval-auc:0.76361	train-auc:0.91894
# [166]	eval-auc:0.76396	train-auc:0.91915
# [167]	eval-auc:0.75674	train-auc:0.91951
# [168]	eval-auc:0.75565	train-auc:0.91963
# [169]	eval-auc:0.75653	train-auc:0.91962
# [170]	eval-auc:0.75741	train-auc:0.91968
# [171]	eval-auc:0.75625	train-auc:0.91989
# [172]	eval-auc:0.75899	train-auc:0.92038
# [173]	eval-auc:0.75801	train-auc:0.92043
# [174]	eval-auc:0.75773	train-auc:0.92052
# [175]	eval-auc:0.75699	train-auc:0.92066
# [176]	eval-auc:0.75569	train-auc:0.92058
# [177]	eval-auc:0.75833	train-auc:0.92085
# [178]	eval-auc:0.75783	train-auc:0.92085
# [179]	eval-auc:0.75759	train-auc:0.92123
# [180]	eval-auc:0.76142	train-auc:0.92133
# [181]	eval-auc:0.76090	train-auc:0.92143
# [182]	eval-auc:0.76192	train-auc:0.92182
# [183]	eval-auc:0.75921	train-auc:0.92210
# [184]	eval-auc:0.76100	train-auc:0.92209
# [185]	eval-auc:0.76463	train-auc:0.92211
# [186]	eval-auc:0.76537	train-auc:0.92224
# [187]	eval-auc:0.76519	train-auc:0.92240
# [188]	eval-auc:0.76371	train-auc:0.92244
# [189]	eval-auc:0.76414	train-auc:0.92271
# [190]	eval-auc:0.76216	train-auc:0.92293
# [191]	eval-auc:0.76751	train-auc:0.92274
# [192]	eval-auc:0.76741	train-auc:0.92294
# [193]	eval-auc:0.76635	train-auc:0.92314
# [194]	eval-auc:0.76776	train-auc:0.92333
# [195]	eval-auc:0.76329	train-auc:0.92316
# [196]	eval-auc:0.76336	train-auc:0.92332
# [197]	eval-auc:0.76202	train-auc:0.92324
# [198]	eval-auc:0.76322	train-auc:0.92349
# [199]	eval-auc:0.76414	train-auc:0.92380
# [200]	eval-auc:0.76572	train-auc:0.92386
# [201]	eval-auc:0.76171	train-auc:0.92382
# [202]	eval-auc:0.76216	train-auc:0.92400
# [203]	eval-auc:0.76044	train-auc:0.92430
# [204]	eval-auc:0.75780	train-auc:0.92429
# [205]	eval-auc:0.75653	train-auc:0.92405
# [206]	eval-auc:0.75424	train-auc:0.92448
# [207]	eval-auc:0.75593	train-auc:0.92463
# [208]	eval-auc:0.75942	train-auc:0.92503
# [209]	eval-auc:0.76002	train-auc:0.92535
# [210]	eval-auc:0.76062	train-auc:0.92560
# [211]	eval-auc:0.75836	train-auc:0.92548
# [212]	eval-auc:0.75878	train-auc:0.92561
# [213]	eval-auc:0.76241	train-auc:0.92584
# [214]	eval-auc:0.76167	train-auc:0.92577
# [215]	eval-auc:0.75787	train-auc:0.92597
# [216]	eval-auc:0.75995	train-auc:0.92634
# [217]	eval-auc:0.75924	train-auc:0.92630
# [218]	eval-auc:0.76171	train-auc:0.92621
# [219]	eval-auc:0.76371	train-auc:0.92603
# [220]	eval-auc:0.75745	train-auc:0.92624
# [221]	eval-auc:0.75723	train-auc:0.92635
# [222]	eval-auc:0.76037	train-auc:0.92643
# [223]	eval-auc:0.76164	train-auc:0.92635
# [224]	eval-auc:0.76385	train-auc:0.92646
# [225]	eval-auc:0.76294	train-auc:0.92665
# [226]	eval-auc:0.76340	train-auc:0.92691
# [227]	eval-auc:0.76414	train-auc:0.92709
# [228]	eval-auc:0.76688	train-auc:0.92702
# [229]	eval-auc:0.76762	train-auc:0.92704
# [230]	eval-auc:0.76755	train-auc:0.92713
# [231]	eval-auc:0.76906	train-auc:0.92712
# [232]	eval-auc:0.76928	train-auc:0.92714
# [233]	eval-auc:0.76924	train-auc:0.92733
# [234]	eval-auc:0.76847	train-auc:0.92738
# [235]	eval-auc:0.76593	train-auc:0.92737
# [236]	eval-auc:0.76748	train-auc:0.92778
# [237]	eval-auc:0.76766	train-auc:0.92777
# [238]	eval-auc:0.76850	train-auc:0.92789
# [239]	eval-auc:0.77142	train-auc:0.92815
# [240]	eval-auc:0.77604	train-auc:0.92831
# [241]	eval-auc:0.77639	train-auc:0.92830
# [242]	eval-auc:0.77878	train-auc:0.92838
# [243]	eval-auc:0.78128	train-auc:0.92846
# [244]	eval-auc:0.78008	train-auc:0.92864
# [245]	eval-auc:0.78086	train-auc:0.92880
# [246]	eval-auc:0.78058	train-auc:0.92891
# [247]	eval-auc:0.78357	train-auc:0.92915
# [248]	eval-auc:0.78392	train-auc:0.92920
# [249]	eval-auc:0.78382	train-auc:0.92921
# [250]	eval-auc:0.78272	train-auc:0.92929
# [251]	eval-auc:0.78174	train-auc:0.92933
# [252]	eval-auc:0.78107	train-auc:0.92944
# [253]	eval-auc:0.77924	train-auc:0.92979
# [254]	eval-auc:0.77913	train-auc:0.92990
# [255]	eval-auc:0.78156	train-auc:0.93023
# [256]	eval-auc:0.78128	train-auc:0.93017
# [257]	eval-auc:0.78079	train-auc:0.93023
# [258]	eval-auc:0.78051	train-auc:0.93034
# [259]	eval-auc:0.78213	train-auc:0.93043
# [260]	eval-auc:0.78033	train-auc:0.93046
# [261]	eval-auc:0.77994	train-auc:0.93061
# [262]	eval-auc:0.77956	train-auc:0.93093
# [263]	eval-auc:0.77704	train-auc:0.93094
# [264]	eval-auc:0.77683	train-auc:0.93105
# [265]	eval-auc:0.78003	train-auc:0.93129
# [266]	eval-auc:0.78260	train-auc:0.93144
# [267]	eval-auc:0.78088	train-auc:0.93143
# [268]	eval-auc:0.78126	train-auc:0.93148
# [269]	eval-auc:0.78158	train-auc:0.93168
# [270]	eval-auc:0.78158	train-auc:0.93177
# [271]	eval-auc:0.77984	train-auc:0.93203
# [272]	eval-auc:0.77741	train-auc:0.93199
# [273]	eval-auc:0.77787	train-auc:0.93206
# [274]	eval-auc:0.77822	train-auc:0.93212
# [275]	eval-auc:0.77699	train-auc:0.93221
# [276]	eval-auc:0.77825	train-auc:0.93222
# [277]	eval-auc:0.77832	train-auc:0.93224
# [278]	eval-auc:0.77748	train-auc:0.93229
# [279]	eval-auc:0.77734	train-auc:0.93245
# [280]	eval-auc:0.77692	train-auc:0.93257
# [281]	eval-auc:0.77794	train-auc:0.93274
# [282]	eval-auc:0.77945	train-auc:0.93277
# [283]	eval-auc:0.77899	train-auc:0.93284
# [284]	eval-auc:0.78336	train-auc:0.93290
# [285]	eval-auc:0.78121	train-auc:0.93296
# [286]	eval-auc:0.78139	train-auc:0.93293
# [287]	eval-auc:0.78111	train-auc:0.93312
# [288]	eval-auc:0.77635	train-auc:0.93313
# [289]	eval-auc:0.77466	train-auc:0.93344
# [290]	eval-auc:0.77540	train-auc:0.93354
# [291]	eval-auc:0.77787	train-auc:0.93367
# [292]	eval-auc:0.78167	train-auc:0.93382
# [293]	eval-auc:0.78135	train-auc:0.93378
# [294]	eval-auc:0.78255	train-auc:0.93378
# [295]	eval-auc:0.78255	train-auc:0.93387
# [296]	eval-auc:0.78117	train-auc:0.93396
# [297]	eval-auc:0.78216	train-auc:0.93391
# [298]	eval-auc:0.78163	train-auc:0.93373
# [299]	eval-auc:0.78459	train-auc:0.93418
# [0]	eval-auc:0.68816	train-auc:0.69286
# [1]	eval-auc:0.72913	train-auc:0.75370
# [2]	eval-auc:0.75582	train-auc:0.78096
# [3]	eval-auc:0.77226	train-auc:0.79678
# [4]	eval-auc:0.78792	train-auc:0.80466
# [5]	eval-auc:0.80690	train-auc:0.81417
# [6]	eval-auc:0.80233	train-auc:0.81419
# [7]	eval-auc:0.80646	train-auc:0.82121
# [8]	eval-auc:0.81900	train-auc:0.83459
# [9]	eval-auc:0.82351	train-auc:0.83654
# [10]	eval-auc:0.82482	train-auc:0.83981
# [11]	eval-auc:0.82643	train-auc:0.84176
# [12]	eval-auc:0.82788	train-auc:0.84466
# [13]	eval-auc:0.82695	train-auc:0.84737
# [14]	eval-auc:0.82774	train-auc:0.84840
# [15]	eval-auc:0.83008	train-auc:0.85056
# [16]	eval-auc:0.83167	train-auc:0.85327
# [17]	eval-auc:0.83478	train-auc:0.85571
# [18]	eval-auc:0.83288	train-auc:0.85668
# [19]	eval-auc:0.83581	train-auc:0.85804
# [20]	eval-auc:0.83766	train-auc:0.85942
# [21]	eval-auc:0.83988	train-auc:0.86120
# [22]	eval-auc:0.84062	train-auc:0.86214
# [23]	eval-auc:0.84463	train-auc:0.86493
# [24]	eval-auc:0.84365	train-auc:0.86568
# [25]	eval-auc:0.84469	train-auc:0.86629
# [26]	eval-auc:0.84659	train-auc:0.86744
# [27]	eval-auc:0.84884	train-auc:0.86869
# [28]	eval-auc:0.84886	train-auc:0.86919
# [29]	eval-auc:0.85039	train-auc:0.87052
# [30]	eval-auc:0.85143	train-auc:0.87095
# [31]	eval-auc:0.85401	train-auc:0.87222
# [32]	eval-auc:0.85614	train-auc:0.87337
# [33]	eval-auc:0.85735	train-auc:0.87428
# [34]	eval-auc:0.85805	train-auc:0.87528
# [35]	eval-auc:0.85939	train-auc:0.87683
# [36]	eval-auc:0.86078	train-auc:0.87782
# [37]	eval-auc:0.86166	train-auc:0.87888
# [38]	eval-auc:0.86203	train-auc:0.87967
# [39]	eval-auc:0.86277	train-auc:0.88122
# [40]	eval-auc:0.86318	train-auc:0.88101
# [41]	eval-auc:0.86408	train-auc:0.88190
# [42]	eval-auc:0.86399	train-auc:0.88233
# [43]	eval-auc:0.86383	train-auc:0.88321
# [44]	eval-auc:0.86368	train-auc:0.88442
# [45]	eval-auc:0.86435	train-auc:0.88528
# [46]	eval-auc:0.86542	train-auc:0.88585
# [47]	eval-auc:0.86538	train-auc:0.88623
# [48]	eval-auc:0.86671	train-auc:0.88803
# [49]	eval-auc:0.86623	train-auc:0.88828
# [50]	eval-auc:0.86603	train-auc:0.88829
# [51]	eval-auc:0.86612	train-auc:0.88935
# [52]	eval-auc:0.86699	train-auc:0.89083
# [53]	eval-auc:0.86801	train-auc:0.89163
# [54]	eval-auc:0.86782	train-auc:0.89186
# [55]	eval-auc:0.86822	train-auc:0.89251
# [56]	eval-auc:0.86945	train-auc:0.89324
# [57]	eval-auc:0.86978	train-auc:0.89382
# [58]	eval-auc:0.86943	train-auc:0.89394
# [59]	eval-auc:0.87006	train-auc:0.89441
# [60]	eval-auc:0.87138	train-auc:0.89519
# [61]	eval-auc:0.87193	train-auc:0.89546
# [62]	eval-auc:0.87313	train-auc:0.89603
# [63]	eval-auc:0.87256	train-auc:0.89649
# [64]	eval-auc:0.87342	train-auc:0.89690
# [65]	eval-auc:0.87344	train-auc:0.89789
# [66]	eval-auc:0.87523	train-auc:0.89879
# [67]	eval-auc:0.87537	train-auc:0.89943
# [68]	eval-auc:0.87537	train-auc:0.89984
# [69]	eval-auc:0.87516	train-auc:0.89994
# [70]	eval-auc:0.87390	train-auc:0.90039
# [71]	eval-auc:0.87309	train-auc:0.90048
# [72]	eval-auc:0.87372	train-auc:0.90091
# [73]	eval-auc:0.87414	train-auc:0.90149
# [74]	eval-auc:0.87497	train-auc:0.90164
# [75]	eval-auc:0.87654	train-auc:0.90179
# [76]	eval-auc:0.87636	train-auc:0.90226
# [77]	eval-auc:0.87724	train-auc:0.90255
# [78]	eval-auc:0.87817	train-auc:0.90308
# [79]	eval-auc:0.87931	train-auc:0.90379
# [80]	eval-auc:0.87863	train-auc:0.90389
# [81]	eval-auc:0.87816	train-auc:0.90401
# [82]	eval-auc:0.87664	train-auc:0.90437
# [83]	eval-auc:0.87639	train-auc:0.90461
# [84]	eval-auc:0.87588	train-auc:0.90518
# [85]	eval-auc:0.87576	train-auc:0.90508
# [86]	eval-auc:0.87518	train-auc:0.90545
# [87]	eval-auc:0.87573	train-auc:0.90545
# [88]	eval-auc:0.87606	train-auc:0.90628
# [89]	eval-auc:0.87444	train-auc:0.90614
# [90]	eval-auc:0.87621	train-auc:0.90673
# [91]	eval-auc:0.87646	train-auc:0.90725
# [92]	eval-auc:0.87696	train-auc:0.90755
# [93]	eval-auc:0.87836	train-auc:0.90785
# [94]	eval-auc:0.87931	train-auc:0.90808
# [95]	eval-auc:0.87918	train-auc:0.90820
# [96]	eval-auc:0.87901	train-auc:0.90863
# [97]	eval-auc:0.87984	train-auc:0.90864
# [98]	eval-auc:0.87863	train-auc:0.90890
# [99]	eval-auc:0.87989	train-auc:0.90926
# [100]	eval-auc:0.88074	train-auc:0.90959
# [101]	eval-auc:0.88140	train-auc:0.90982
# [102]	eval-auc:0.88199	train-auc:0.90998
# [103]	eval-auc:0.88162	train-auc:0.91037
# [104]	eval-auc:0.88121	train-auc:0.91072
# [105]	eval-auc:0.88036	train-auc:0.91093
# [106]	eval-auc:0.88114	train-auc:0.91124
# [107]	eval-auc:0.88136	train-auc:0.91140
# [108]	eval-auc:0.88136	train-auc:0.91199
# [109]	eval-auc:0.88173	train-auc:0.91198
# [110]	eval-auc:0.88159	train-auc:0.91190
# [111]	eval-auc:0.88244	train-auc:0.91194
# [112]	eval-auc:0.88284	train-auc:0.91229
# [113]	eval-auc:0.88356	train-auc:0.91258
# [114]	eval-auc:0.88378	train-auc:0.91273
# [115]	eval-auc:0.88325	train-auc:0.91270
# [116]	eval-auc:0.88343	train-auc:0.91290
# [117]	eval-auc:0.88406	train-auc:0.91326
# [118]	eval-auc:0.88435	train-auc:0.91365
# [119]	eval-auc:0.88402	train-auc:0.91376
# [120]	eval-auc:0.88356	train-auc:0.91424
# [121]	eval-auc:0.88372	train-auc:0.91446
# [122]	eval-auc:0.88341	train-auc:0.91466
# [123]	eval-auc:0.88345	train-auc:0.91460
# [124]	eval-auc:0.88355	train-auc:0.91489
# [125]	eval-auc:0.88370	train-auc:0.91552
# [126]	eval-auc:0.88384	train-auc:0.91587
# [127]	eval-auc:0.88404	train-auc:0.91598
# [128]	eval-auc:0.88469	train-auc:0.91605
# [129]	eval-auc:0.88455	train-auc:0.91604
# [130]	eval-auc:0.88506	train-auc:0.91626
# [131]	eval-auc:0.88550	train-auc:0.91639
# [132]	eval-auc:0.88587	train-auc:0.91653
# [133]	eval-auc:0.88607	train-auc:0.91646
# [134]	eval-auc:0.88580	train-auc:0.91651
# [135]	eval-auc:0.88561	train-auc:0.91680
# [136]	eval-auc:0.88618	train-auc:0.91697
# [137]	eval-auc:0.88722	train-auc:0.91713
# [138]	eval-auc:0.88618	train-auc:0.91708
# [139]	eval-auc:0.88583	train-auc:0.91723
# [140]	eval-auc:0.88620	train-auc:0.91735
# [141]	eval-auc:0.88647	train-auc:0.91749
# [142]	eval-auc:0.88728	train-auc:0.91822
# [143]	eval-auc:0.88776	train-auc:0.91810
# [144]	eval-auc:0.88705	train-auc:0.91842
# [145]	eval-auc:0.88776	train-auc:0.91868
# [146]	eval-auc:0.88735	train-auc:0.91894
# [147]	eval-auc:0.88766	train-auc:0.91910
# [148]	eval-auc:0.88606	train-auc:0.91917
# [149]	eval-auc:0.88587	train-auc:0.91944
# [150]	eval-auc:0.88595	train-auc:0.91952
# [151]	eval-auc:0.88663	train-auc:0.92009
# [152]	eval-auc:0.88725	train-auc:0.92030
# [153]	eval-auc:0.88757	train-auc:0.92043
# [154]	eval-auc:0.88713	train-auc:0.92067
# [155]	eval-auc:0.88748	train-auc:0.92096
# [156]	eval-auc:0.88743	train-auc:0.92111
# [157]	eval-auc:0.88761	train-auc:0.92118
# [158]	eval-auc:0.88672	train-auc:0.92108
# [159]	eval-auc:0.88650	train-auc:0.92114
# [160]	eval-auc:0.88731	train-auc:0.92120
# [161]	eval-auc:0.88750	train-auc:0.92131
# [162]	eval-auc:0.88816	train-auc:0.92173
# [163]	eval-auc:0.88809	train-auc:0.92194
# [164]	eval-auc:0.88818	train-auc:0.92202
# [165]	eval-auc:0.88803	train-auc:0.92225
# [166]	eval-auc:0.88870	train-auc:0.92227
# [167]	eval-auc:0.88918	train-auc:0.92236
# [168]	eval-auc:0.88887	train-auc:0.92263
# [169]	eval-auc:0.88806	train-auc:0.92287
# [170]	eval-auc:0.88794	train-auc:0.92292
# [171]	eval-auc:0.88763	train-auc:0.92294
# [172]	eval-auc:0.88757	train-auc:0.92313
# [173]	eval-auc:0.88683	train-auc:0.92321
# [174]	eval-auc:0.88714	train-auc:0.92356
# [175]	eval-auc:0.88750	train-auc:0.92374
# [176]	eval-auc:0.88776	train-auc:0.92371
# [177]	eval-auc:0.88770	train-auc:0.92391
# [178]	eval-auc:0.88759	train-auc:0.92402
# [179]	eval-auc:0.88835	train-auc:0.92402
# [180]	eval-auc:0.88847	train-auc:0.92427
# [181]	eval-auc:0.88920	train-auc:0.92444
# [182]	eval-auc:0.88980	train-auc:0.92484
# [183]	eval-auc:0.88998	train-auc:0.92508
# [184]	eval-auc:0.89058	train-auc:0.92514
# [185]	eval-auc:0.89070	train-auc:0.92501
# [186]	eval-auc:0.89062	train-auc:0.92521
# [187]	eval-auc:0.89101	train-auc:0.92535
# [188]	eval-auc:0.89169	train-auc:0.92538
# [189]	eval-auc:0.89182	train-auc:0.92538
# [190]	eval-auc:0.89187	train-auc:0.92546
# [191]	eval-auc:0.89180	train-auc:0.92563
# [192]	eval-auc:0.89160	train-auc:0.92576
# [193]	eval-auc:0.89173	train-auc:0.92596
# [194]	eval-auc:0.89188	train-auc:0.92592
# [195]	eval-auc:0.89062	train-auc:0.92604
# [196]	eval-auc:0.89060	train-auc:0.92625
# [197]	eval-auc:0.89154	train-auc:0.92646
# [198]	eval-auc:0.89188	train-auc:0.92664
# [199]	eval-auc:0.89176	train-auc:0.92679
# [200]	eval-auc:0.89177	train-auc:0.92682
# [201]	eval-auc:0.89105	train-auc:0.92686
# [202]	eval-auc:0.89080	train-auc:0.92696
# [203]	eval-auc:0.89042	train-auc:0.92683
# [204]	eval-auc:0.89040	train-auc:0.92716
# [205]	eval-auc:0.89087	train-auc:0.92726
# [206]	eval-auc:0.89117	train-auc:0.92741
# [207]	eval-auc:0.89128	train-auc:0.92742
# [208]	eval-auc:0.89101	train-auc:0.92757
# [209]	eval-auc:0.89125	train-auc:0.92768
# [210]	eval-auc:0.89155	train-auc:0.92775
# [211]	eval-auc:0.89127	train-auc:0.92779
# [212]	eval-auc:0.89099	train-auc:0.92803
# [213]	eval-auc:0.89142	train-auc:0.92814
# [214]	eval-auc:0.89124	train-auc:0.92816
# [215]	eval-auc:0.89142	train-auc:0.92847
# [216]	eval-auc:0.89176	train-auc:0.92860
# [217]	eval-auc:0.89157	train-auc:0.92843
# [218]	eval-auc:0.89158	train-auc:0.92853
# [219]	eval-auc:0.89170	train-auc:0.92891
# [220]	eval-auc:0.89202	train-auc:0.92900
# [221]	eval-auc:0.89267	train-auc:0.92898
# [222]	eval-auc:0.89253	train-auc:0.92912
# [223]	eval-auc:0.89339	train-auc:0.92924
# [224]	eval-auc:0.89249	train-auc:0.92938
# [225]	eval-auc:0.89199	train-auc:0.92960
# [226]	eval-auc:0.89251	train-auc:0.92980
# [227]	eval-auc:0.89286	train-auc:0.92999
# [228]	eval-auc:0.89299	train-auc:0.93009
# [229]	eval-auc:0.89276	train-auc:0.93029
# [230]	eval-auc:0.89282	train-auc:0.93038
# [231]	eval-auc:0.89261	train-auc:0.93039
# [232]	eval-auc:0.89243	train-auc:0.93057
# [233]	eval-auc:0.89262	train-auc:0.93088
# [234]	eval-auc:0.89321	train-auc:0.93087
# [235]	eval-auc:0.89294	train-auc:0.93099
# [236]	eval-auc:0.89305	train-auc:0.93109
# [237]	eval-auc:0.89319	train-auc:0.93120
# [238]	eval-auc:0.89395	train-auc:0.93137
# [239]	eval-auc:0.89376	train-auc:0.93144
# [240]	eval-auc:0.89295	train-auc:0.93158
# [241]	eval-auc:0.89327	train-auc:0.93143
# [242]	eval-auc:0.89375	train-auc:0.93172
# [243]	eval-auc:0.89376	train-auc:0.93190
# [244]	eval-auc:0.89431	train-auc:0.93179
# [245]	eval-auc:0.89423	train-auc:0.93199
# [246]	eval-auc:0.89442	train-auc:0.93207
# [247]	eval-auc:0.89458	train-auc:0.93202
# [248]	eval-auc:0.89458	train-auc:0.93209
# [249]	eval-auc:0.89434	train-auc:0.93227
# [250]	eval-auc:0.89427	train-auc:0.93216
# [251]	eval-auc:0.89514	train-auc:0.93237
# [252]	eval-auc:0.89576	train-auc:0.93229
# [253]	eval-auc:0.89626	train-auc:0.93221
# [254]	eval-auc:0.89630	train-auc:0.93230
# [255]	eval-auc:0.89652	train-auc:0.93238
# [256]	eval-auc:0.89628	train-auc:0.93241
# [257]	eval-auc:0.89629	train-auc:0.93245
# [258]	eval-auc:0.89614	train-auc:0.93253
# [259]	eval-auc:0.89662	train-auc:0.93261
# [260]	eval-auc:0.89703	train-auc:0.93279
# [261]	eval-auc:0.89670	train-auc:0.93271
# [262]	eval-auc:0.89622	train-auc:0.93273
# [263]	eval-auc:0.89654	train-auc:0.93276
# [264]	eval-auc:0.89685	train-auc:0.93277
# [265]	eval-auc:0.89639	train-auc:0.93272
# [266]	eval-auc:0.89660	train-auc:0.93287
# [267]	eval-auc:0.89700	train-auc:0.93300
# [268]	eval-auc:0.89739	train-auc:0.93301
# [269]	eval-auc:0.89743	train-auc:0.93303
# [270]	eval-auc:0.89802	train-auc:0.93317
# [271]	eval-auc:0.89776	train-auc:0.93319
# [272]	eval-auc:0.89737	train-auc:0.93323
# [273]	eval-auc:0.89769	train-auc:0.93337
# [274]	eval-auc:0.89700	train-auc:0.93340
# [275]	eval-auc:0.89726	train-auc:0.93351
# [276]	eval-auc:0.89750	train-auc:0.93371
# [277]	eval-auc:0.89778	train-auc:0.93378
# [278]	eval-auc:0.89772	train-auc:0.93375
# [279]	eval-auc:0.89824	train-auc:0.93385
# [280]	eval-auc:0.89841	train-auc:0.93393
# [281]	eval-auc:0.89841	train-auc:0.93407
# [282]	eval-auc:0.89848	train-auc:0.93440
# [283]	eval-auc:0.89872	train-auc:0.93451
# [284]	eval-auc:0.89900	train-auc:0.93448
# [285]	eval-auc:0.89915	train-auc:0.93453
# [286]	eval-auc:0.89941	train-auc:0.93459
# [287]	eval-auc:0.89946	train-auc:0.93470
# [288]	eval-auc:0.89944	train-auc:0.93486
# [289]	eval-auc:0.89931	train-auc:0.93505
# [290]	eval-auc:0.89918	train-auc:0.93514
# [291]	eval-auc:0.89969	train-auc:0.93530
# [292]	eval-auc:0.89989	train-auc:0.93535
# [293]	eval-auc:0.89969	train-auc:0.93537
# [294]	eval-auc:0.89939	train-auc:0.93545
# [295]	eval-auc:0.89921	train-auc:0.93555
# [296]	eval-auc:0.89872	train-auc:0.93546
# [297]	eval-auc:0.89837	train-auc:0.93564
# [298]	eval-auc:0.89844	train-auc:0.93589
# [299]	eval-auc:0.89874	train-auc:0.93594

# %%
eval_p38 = pd.DataFrame(eval_p38).T
eval_p38.to_csv('../../../../Desktop/binding/thesis english/Results/2-XGBoost/p38.csv')
eval_p38
# Out:
#          roc_auc     tn    fp    fn     tp       map  precision    recall  \
# Test    0.869295  315.0  45.0  66.0  111.0  0.739396   0.711538  0.627119
# Ave     0.784590  233.0  30.0  72.0   36.0  0.555550   0.545455  0.333333
# Random  0.898743  327.0  36.0  63.0  138.0  0.836514   0.793103  0.686567
#
#         accuracy
# Test    0.793296
# Ave     0.725067
# Random  0.824468

# %%
eval_akt1 = {}
for i in range(len(train_list_akt1)):
    if i == 1:
        smi = train_list_akt1[i].rdkit
        mols = [Chem.MolFromSmiles(smi) for smi in smi]
        ECFP = [AllChem.GetMorganFingerprintAsBitVect(x,2,nBits=1024) for x in mols]
        a = np.array(ECFP)
        ECFP_smiles = a.astype(np.float32)
        train_labels = Y_train_akt1
        dmatrix_train = xgb.DMatrix(data = ECFP_smiles,label = train_labels)
        
        smi = val_list_akt1[i].rdkit
        mols = [Chem.MolFromSmiles(smi) for smi in smi]
        ECFP = [AllChem.GetMorganFingerprintAsBitVect(x,2,nBits=1024) for x in mols]
        a = np.array(ECFP)
        ECFP_smiles = a.astype(np.float32)
        val_labels = Y_val_akt1
        dmatrix_val = xgb.DMatrix(data = ECFP_smiles,label = val_labels)
        del smi,mols,ECFP,a,ECFP_smiles
        
        evalist = [(dmatrix_val,'eval'),(dmatrix_train,'train')]
        model = class_xgb.build_model(dmatrix_train,evalist,True,300)
    else:
        dmatrix_train,train_labels = class_xgb.to_xgb_input(train_list_akt1[i])
        dmatrix_val,val_labels = class_xgb.to_xgb_input(val_list_akt1[i])
        evalist = [(dmatrix_val,'eval'),(dmatrix_train,'train')]
        model = class_xgb.build_model(dmatrix_train,evalist,True,300)
    
    y_pred_val = model.predict(dmatrix_val)
    if i == 0:
        eval_akt1['Test'] = calculate_metrics(np.array(val_labels),y_pred_val)
    elif i == 1:
        eval_akt1['Random'] = calculate_metrics(np.array(val_labels),y_pred_val)
# Out:
# [0]	eval-auc:0.67759	train-auc:0.69365
# [1]	eval-auc:0.71901	train-auc:0.73987
# [2]	eval-auc:0.75572	train-auc:0.78521
# [3]	eval-auc:0.78253	train-auc:0.80836
# [4]	eval-auc:0.78916	train-auc:0.81246
# [5]	eval-auc:0.79537	train-auc:0.81803
# [6]	eval-auc:0.79456	train-auc:0.82755
# [7]	eval-auc:0.81010	train-auc:0.83523
# [8]	eval-auc:0.80760	train-auc:0.83491
# [9]	eval-auc:0.81445	train-auc:0.84006
# [10]	eval-auc:0.82182	train-auc:0.84369
# [11]	eval-auc:0.82740	train-auc:0.84862
# [12]	eval-auc:0.82874	train-auc:0.85088
# [13]	eval-auc:0.83487	train-auc:0.85358
# [14]	eval-auc:0.83439	train-auc:0.85654
# [15]	eval-auc:0.83587	train-auc:0.86127
# [16]	eval-auc:0.83800	train-auc:0.86342
# [17]	eval-auc:0.83927	train-auc:0.86329
# [18]	eval-auc:0.84213	train-auc:0.86728
# [19]	eval-auc:0.84192	train-auc:0.86889
# [20]	eval-auc:0.84106	train-auc:0.87017
# [21]	eval-auc:0.84483	train-auc:0.87146
# [22]	eval-auc:0.84569	train-auc:0.87176
# [23]	eval-auc:0.84508	train-auc:0.87222
# [24]	eval-auc:0.84598	train-auc:0.87198
# [25]	eval-auc:0.84916	train-auc:0.87432
# [26]	eval-auc:0.84750	train-auc:0.87537
# [27]	eval-auc:0.84796	train-auc:0.87544
# [28]	eval-auc:0.84759	train-auc:0.87774
# [29]	eval-auc:0.84703	train-auc:0.87883
# [30]	eval-auc:0.84691	train-auc:0.87987
# [31]	eval-auc:0.84784	train-auc:0.88136
# [32]	eval-auc:0.84576	train-auc:0.88299
# [33]	eval-auc:0.84830	train-auc:0.88316
# [34]	eval-auc:0.84943	train-auc:0.88438
# [35]	eval-auc:0.84739	train-auc:0.88630
# [36]	eval-auc:0.84739	train-auc:0.88681
# [37]	eval-auc:0.84907	train-auc:0.88601
# [38]	eval-auc:0.84971	train-auc:0.88630
# [39]	eval-auc:0.84803	train-auc:0.88791
# [40]	eval-auc:0.84834	train-auc:0.88836
# [41]	eval-auc:0.84812	train-auc:0.88888
# [42]	eval-auc:0.84862	train-auc:0.89044
# [43]	eval-auc:0.84898	train-auc:0.89112
# [44]	eval-auc:0.84753	train-auc:0.89251
# [45]	eval-auc:0.84794	train-auc:0.89267
# [46]	eval-auc:0.84757	train-auc:0.89261
# [47]	eval-auc:0.84844	train-auc:0.89312
# [48]	eval-auc:0.85016	train-auc:0.89314
# [49]	eval-auc:0.84998	train-auc:0.89328
# [50]	eval-auc:0.85002	train-auc:0.89318
# [51]	eval-auc:0.85247	train-auc:0.89454
# [52]	eval-auc:0.85234	train-auc:0.89561
# [53]	eval-auc:0.85184	train-auc:0.89617
# [54]	eval-auc:0.85116	train-auc:0.89613
# [55]	eval-auc:0.85125	train-auc:0.89627
# [56]	eval-auc:0.85061	train-auc:0.89667
# [57]	eval-auc:0.85370	train-auc:0.89722
# [58]	eval-auc:0.85279	train-auc:0.89719
# [59]	eval-auc:0.85318	train-auc:0.89781
# [60]	eval-auc:0.85256	train-auc:0.89793
# [61]	eval-auc:0.85311	train-auc:0.89774
# [62]	eval-auc:0.85488	train-auc:0.89844
# [63]	eval-auc:0.85569	train-auc:0.89900
# [64]	eval-auc:0.85565	train-auc:0.89967
# [65]	eval-auc:0.85597	train-auc:0.89983
# [66]	eval-auc:0.85510	train-auc:0.89983
# [67]	eval-auc:0.85479	train-auc:0.89999
# [68]	eval-auc:0.85574	train-auc:0.90021
# [69]	eval-auc:0.85633	train-auc:0.90068
# [70]	eval-auc:0.85597	train-auc:0.90084
# [71]	eval-auc:0.85651	train-auc:0.90151
# [72]	eval-auc:0.85465	train-auc:0.90174
# [73]	eval-auc:0.85411	train-auc:0.90214
# [74]	eval-auc:0.85356	train-auc:0.90229
# [75]	eval-auc:0.85449	train-auc:0.90251
# [76]	eval-auc:0.85422	train-auc:0.90312
# [77]	eval-auc:0.85386	train-auc:0.90373
# [78]	eval-auc:0.85427	train-auc:0.90374
# [79]	eval-auc:0.85513	train-auc:0.90336
# [80]	eval-auc:0.85454	train-auc:0.90347
# [81]	eval-auc:0.85465	train-auc:0.90369
# [82]	eval-auc:0.85447	train-auc:0.90392
# [83]	eval-auc:0.85447	train-auc:0.90393
# [84]	eval-auc:0.85452	train-auc:0.90409
# [85]	eval-auc:0.85513	train-auc:0.90355
# [86]	eval-auc:0.85481	train-auc:0.90376
# [87]	eval-auc:0.85517	train-auc:0.90419
# [88]	eval-auc:0.85531	train-auc:0.90413
# [89]	eval-auc:0.85481	train-auc:0.90460
# [90]	eval-auc:0.85504	train-auc:0.90501
# [91]	eval-auc:0.85585	train-auc:0.90518
# [92]	eval-auc:0.85504	train-auc:0.90550
# [93]	eval-auc:0.85422	train-auc:0.90552
# [94]	eval-auc:0.85454	train-auc:0.90589
# [95]	eval-auc:0.85558	train-auc:0.90569
# [96]	eval-auc:0.85640	train-auc:0.90588
# [97]	eval-auc:0.85526	train-auc:0.90624
# [98]	eval-auc:0.85631	train-auc:0.90685
# [99]	eval-auc:0.85608	train-auc:0.90694
# [100]	eval-auc:0.85567	train-auc:0.90689
# [101]	eval-auc:0.85635	train-auc:0.90680
# [102]	eval-auc:0.85608	train-auc:0.90696
# [103]	eval-auc:0.85758	train-auc:0.90690
# [104]	eval-auc:0.85794	train-auc:0.90689
# [105]	eval-auc:0.85753	train-auc:0.90693
# [106]	eval-auc:0.85744	train-auc:0.90722
# [107]	eval-auc:0.85685	train-auc:0.90724
# [108]	eval-auc:0.85771	train-auc:0.90760
# [109]	eval-auc:0.85821	train-auc:0.90769
# [110]	eval-auc:0.85971	train-auc:0.90738
# [111]	eval-auc:0.85966	train-auc:0.90738
# [112]	eval-auc:0.86003	train-auc:0.90789
# [113]	eval-auc:0.85839	train-auc:0.90830
# [114]	eval-auc:0.85926	train-auc:0.90842
# [115]	eval-auc:0.85830	train-auc:0.90886
# [116]	eval-auc:0.85789	train-auc:0.90917
# [117]	eval-auc:0.85785	train-auc:0.90923
# [118]	eval-auc:0.85771	train-auc:0.90942
# [119]	eval-auc:0.85740	train-auc:0.90927
# [120]	eval-auc:0.85740	train-auc:0.90910
# [121]	eval-auc:0.85753	train-auc:0.90912
# [122]	eval-auc:0.85767	train-auc:0.90919
# [123]	eval-auc:0.85830	train-auc:0.90947
# [124]	eval-auc:0.85767	train-auc:0.91011
# [125]	eval-auc:0.85887	train-auc:0.91007
# [126]	eval-auc:0.85814	train-auc:0.91014
# [127]	eval-auc:0.85801	train-auc:0.90996
# [128]	eval-auc:0.85910	train-auc:0.91000
# [129]	eval-auc:0.85828	train-auc:0.91055
# [130]	eval-auc:0.85828	train-auc:0.91065
# [131]	eval-auc:0.85819	train-auc:0.91073
# [132]	eval-auc:0.85901	train-auc:0.91082
# [133]	eval-auc:0.85910	train-auc:0.91113
# [134]	eval-auc:0.85960	train-auc:0.91116
# [135]	eval-auc:0.85960	train-auc:0.91133
# [136]	eval-auc:0.85851	train-auc:0.91147
# [137]	eval-auc:0.85892	train-auc:0.91127
# [138]	eval-auc:0.85842	train-auc:0.91177
# [139]	eval-auc:0.85864	train-auc:0.91168
# [140]	eval-auc:0.85846	train-auc:0.91185
# [141]	eval-auc:0.85819	train-auc:0.91178
# [142]	eval-auc:0.85796	train-auc:0.91163
# [143]	eval-auc:0.85814	train-auc:0.91211
# [144]	eval-auc:0.85942	train-auc:0.91180
# [145]	eval-auc:0.85932	train-auc:0.91183
# [146]	eval-auc:0.85828	train-auc:0.91192
# [147]	eval-auc:0.85833	train-auc:0.91214
# [148]	eval-auc:0.85787	train-auc:0.91224
# [149]	eval-auc:0.85796	train-auc:0.91224
# [150]	eval-auc:0.85932	train-auc:0.91218
# [151]	eval-auc:0.85982	train-auc:0.91228
# [152]	eval-auc:0.85969	train-auc:0.91254
# [153]	eval-auc:0.85923	train-auc:0.91237
# [154]	eval-auc:0.85896	train-auc:0.91253
# [155]	eval-auc:0.85978	train-auc:0.91282
# [156]	eval-auc:0.86014	train-auc:0.91303
# [157]	eval-auc:0.86037	train-auc:0.91277
# [158]	eval-auc:0.86123	train-auc:0.91305
# [159]	eval-auc:0.86078	train-auc:0.91297
# [160]	eval-auc:0.86064	train-auc:0.91295
# [161]	eval-auc:0.86096	train-auc:0.91293
# [162]	eval-auc:0.86105	train-auc:0.91292
# [163]	eval-auc:0.86128	train-auc:0.91288
# [164]	eval-auc:0.86082	train-auc:0.91302
# [165]	eval-auc:0.86023	train-auc:0.91347
# [166]	eval-auc:0.86005	train-auc:0.91364
# [167]	eval-auc:0.85991	train-auc:0.91367
# [168]	eval-auc:0.85982	train-auc:0.91378
# [169]	eval-auc:0.86023	train-auc:0.91371
# [170]	eval-auc:0.86032	train-auc:0.91382
# [171]	eval-auc:0.86041	train-auc:0.91390
# [172]	eval-auc:0.86014	train-auc:0.91386
# [173]	eval-auc:0.86014	train-auc:0.91383
# [174]	eval-auc:0.86168	train-auc:0.91363
# [175]	eval-auc:0.86073	train-auc:0.91388
# [176]	eval-auc:0.86100	train-auc:0.91394
# [177]	eval-auc:0.86096	train-auc:0.91421
# [178]	eval-auc:0.86046	train-auc:0.91414
# [179]	eval-auc:0.86037	train-auc:0.91420
# [180]	eval-auc:0.85973	train-auc:0.91416
# [181]	eval-auc:0.86023	train-auc:0.91429
# [182]	eval-auc:0.85987	train-auc:0.91440
# [183]	eval-auc:0.86073	train-auc:0.91439
# [184]	eval-auc:0.86073	train-auc:0.91437
# [185]	eval-auc:0.86046	train-auc:0.91430
# [186]	eval-auc:0.86005	train-auc:0.91432
# [187]	eval-auc:0.85860	train-auc:0.91442
# [188]	eval-auc:0.85892	train-auc:0.91454
# [189]	eval-auc:0.85973	train-auc:0.91456
# [190]	eval-auc:0.86100	train-auc:0.91469
# [191]	eval-auc:0.86159	train-auc:0.91478
# [192]	eval-auc:0.86241	train-auc:0.91501
# [193]	eval-auc:0.86264	train-auc:0.91505
# [194]	eval-auc:0.86350	train-auc:0.91504
# [195]	eval-auc:0.86350	train-auc:0.91504
# [196]	eval-auc:0.86386	train-auc:0.91506
# [197]	eval-auc:0.86436	train-auc:0.91507
# [198]	eval-auc:0.86459	train-auc:0.91494
# [199]	eval-auc:0.86422	train-auc:0.91496
# [200]	eval-auc:0.86395	train-auc:0.91494
# [201]	eval-auc:0.86422	train-auc:0.91517
# [202]	eval-auc:0.86445	train-auc:0.91531
# [203]	eval-auc:0.86550	train-auc:0.91558
# [204]	eval-auc:0.86436	train-auc:0.91556
# [205]	eval-auc:0.86445	train-auc:0.91563
# [206]	eval-auc:0.86518	train-auc:0.91573
# [207]	eval-auc:0.86640	train-auc:0.91563
# [208]	eval-auc:0.86649	train-auc:0.91553
# [209]	eval-auc:0.86649	train-auc:0.91555
# [210]	eval-auc:0.86572	train-auc:0.91541
# [211]	eval-auc:0.86550	train-auc:0.91552
# [212]	eval-auc:0.86595	train-auc:0.91569
# [213]	eval-auc:0.86581	train-auc:0.91565
# [214]	eval-auc:0.86572	train-auc:0.91566
# [215]	eval-auc:0.86522	train-auc:0.91569
# [216]	eval-auc:0.86604	train-auc:0.91573
# [217]	eval-auc:0.86699	train-auc:0.91590
# [218]	eval-auc:0.86790	train-auc:0.91589
# [219]	eval-auc:0.86790	train-auc:0.91586
# [220]	eval-auc:0.86844	train-auc:0.91589
# [221]	eval-auc:0.86885	train-auc:0.91575
# [222]	eval-auc:0.86881	train-auc:0.91582
# [223]	eval-auc:0.86894	train-auc:0.91588
# [224]	eval-auc:0.86899	train-auc:0.91595
# [225]	eval-auc:0.86887	train-auc:0.91616
# [226]	eval-auc:0.86960	train-auc:0.91628
# [227]	eval-auc:0.87014	train-auc:0.91639
# [228]	eval-auc:0.87024	train-auc:0.91652
# [229]	eval-auc:0.87001	train-auc:0.91667
# [230]	eval-auc:0.86983	train-auc:0.91674
# [231]	eval-auc:0.87037	train-auc:0.91677
# [232]	eval-auc:0.87069	train-auc:0.91687
# [233]	eval-auc:0.87019	train-auc:0.91692
# [234]	eval-auc:0.87096	train-auc:0.91680
# [235]	eval-auc:0.87123	train-auc:0.91682
# [236]	eval-auc:0.87105	train-auc:0.91690
# [237]	eval-auc:0.87074	train-auc:0.91697
# [238]	eval-auc:0.86919	train-auc:0.91699
# [239]	eval-auc:0.86987	train-auc:0.91693
# [240]	eval-auc:0.86928	train-auc:0.91698
# [241]	eval-auc:0.86996	train-auc:0.91692
# [242]	eval-auc:0.87001	train-auc:0.91687
# [243]	eval-auc:0.86969	train-auc:0.91675
# [244]	eval-auc:0.87019	train-auc:0.91667
# [245]	eval-auc:0.87046	train-auc:0.91703
# [246]	eval-auc:0.87005	train-auc:0.91703
# [247]	eval-auc:0.87069	train-auc:0.91690
# [248]	eval-auc:0.87037	train-auc:0.91716
# [249]	eval-auc:0.87037	train-auc:0.91740
# [250]	eval-auc:0.87046	train-auc:0.91738
# [251]	eval-auc:0.86992	train-auc:0.91739
# [252]	eval-auc:0.86978	train-auc:0.91753
# [253]	eval-auc:0.86987	train-auc:0.91765
# [254]	eval-auc:0.86996	train-auc:0.91773
# [255]	eval-auc:0.86996	train-auc:0.91771
# [256]	eval-auc:0.87001	train-auc:0.91772
# [257]	eval-auc:0.87037	train-auc:0.91762
# [258]	eval-auc:0.87005	train-auc:0.91776
# [259]	eval-auc:0.87037	train-auc:0.91773
# [260]	eval-auc:0.87030	train-auc:0.91789
# [261]	eval-auc:0.86999	train-auc:0.91783
# [262]	eval-auc:0.87042	train-auc:0.91790
# [263]	eval-auc:0.87024	train-auc:0.91795
# [264]	eval-auc:0.86978	train-auc:0.91815
# [265]	eval-auc:0.87001	train-auc:0.91811
# [266]	eval-auc:0.87046	train-auc:0.91806
# [267]	eval-auc:0.87069	train-auc:0.91815
# [268]	eval-auc:0.87064	train-auc:0.91808
# [269]	eval-auc:0.86996	train-auc:0.91803
# [270]	eval-auc:0.86965	train-auc:0.91805
# [271]	eval-auc:0.86924	train-auc:0.91817
# [272]	eval-auc:0.86883	train-auc:0.91803
# [273]	eval-auc:0.86974	train-auc:0.91806
# [274]	eval-auc:0.86992	train-auc:0.91817
# [275]	eval-auc:0.86960	train-auc:0.91824
# [276]	eval-auc:0.86992	train-auc:0.91835
# [277]	eval-auc:0.86937	train-auc:0.91848
# [278]	eval-auc:0.86942	train-auc:0.91852
# [279]	eval-auc:0.86992	train-auc:0.91850
# [280]	eval-auc:0.87078	train-auc:0.91880
# [281]	eval-auc:0.87033	train-auc:0.91883
# [282]	eval-auc:0.87051	train-auc:0.91880
# [283]	eval-auc:0.87074	train-auc:0.91881
# [284]	eval-auc:0.87005	train-auc:0.91890
# [285]	eval-auc:0.86969	train-auc:0.91895
# [286]	eval-auc:0.86960	train-auc:0.91899
# [287]	eval-auc:0.87005	train-auc:0.91897
# [288]	eval-auc:0.87055	train-auc:0.91900
# [289]	eval-auc:0.87092	train-auc:0.91895
# [290]	eval-auc:0.87119	train-auc:0.91895
# [291]	eval-auc:0.87160	train-auc:0.91914
# [292]	eval-auc:0.87142	train-auc:0.91919
# [293]	eval-auc:0.87246	train-auc:0.91940
# [294]	eval-auc:0.87305	train-auc:0.91964
# [295]	eval-auc:0.87323	train-auc:0.91972
# [296]	eval-auc:0.87341	train-auc:0.91963
# [297]	eval-auc:0.87359	train-auc:0.91968
# [298]	eval-auc:0.87278	train-auc:0.91981
# [299]	eval-auc:0.87269	train-auc:0.91978
# [0]	eval-auc:0.71403	train-auc:0.67581
# [1]	eval-auc:0.75367	train-auc:0.72495
# [2]	eval-auc:0.76424	train-auc:0.76488
# [3]	eval-auc:0.78639	train-auc:0.78156
# [4]	eval-auc:0.79579	train-auc:0.80611
# [5]	eval-auc:0.80169	train-auc:0.81147
# [6]	eval-auc:0.80975	train-auc:0.83136
# [7]	eval-auc:0.80993	train-auc:0.83457
# [8]	eval-auc:0.80536	train-auc:0.83539
# [9]	eval-auc:0.80932	train-auc:0.83913
# [10]	eval-auc:0.81506	train-auc:0.84469
# [11]	eval-auc:0.81804	train-auc:0.84617
# [12]	eval-auc:0.81685	train-auc:0.84898
# [13]	eval-auc:0.82189	train-auc:0.85030
# [14]	eval-auc:0.82143	train-auc:0.85046
# [15]	eval-auc:0.82745	train-auc:0.85216
# [16]	eval-auc:0.82825	train-auc:0.85496
# [17]	eval-auc:0.82797	train-auc:0.85758
# [18]	eval-auc:0.82992	train-auc:0.86104
# [19]	eval-auc:0.83413	train-auc:0.86474
# [20]	eval-auc:0.83441	train-auc:0.86512
# [21]	eval-auc:0.83627	train-auc:0.86637
# [22]	eval-auc:0.83699	train-auc:0.86742
# [23]	eval-auc:0.83705	train-auc:0.86881
# [24]	eval-auc:0.83608	train-auc:0.86962
# [25]	eval-auc:0.83741	train-auc:0.87059
# [26]	eval-auc:0.83915	train-auc:0.87261
# [27]	eval-auc:0.83975	train-auc:0.87268
# [28]	eval-auc:0.83973	train-auc:0.87336
# [29]	eval-auc:0.83913	train-auc:0.87457
# [30]	eval-auc:0.83957	train-auc:0.87504
# [31]	eval-auc:0.84021	train-auc:0.87504
# [32]	eval-auc:0.83937	train-auc:0.87562
# [33]	eval-auc:0.84299	train-auc:0.87738
# [34]	eval-auc:0.84553	train-auc:0.87882
# [35]	eval-auc:0.84654	train-auc:0.88023
# [36]	eval-auc:0.84666	train-auc:0.88087
# [37]	eval-auc:0.85076	train-auc:0.88227
# [38]	eval-auc:0.85105	train-auc:0.88321
# [39]	eval-auc:0.85215	train-auc:0.88378
# [40]	eval-auc:0.85292	train-auc:0.88395
# [41]	eval-auc:0.85425	train-auc:0.88403
# [42]	eval-auc:0.85260	train-auc:0.88376
# [43]	eval-auc:0.85369	train-auc:0.88407
# [44]	eval-auc:0.85377	train-auc:0.88499
# [45]	eval-auc:0.85489	train-auc:0.88581
# [46]	eval-auc:0.85642	train-auc:0.88579
# [47]	eval-auc:0.85689	train-auc:0.88631
# [48]	eval-auc:0.85761	train-auc:0.88727
# [49]	eval-auc:0.85657	train-auc:0.88725
# [50]	eval-auc:0.85659	train-auc:0.88757
# [51]	eval-auc:0.85795	train-auc:0.88825
# [52]	eval-auc:0.85852	train-auc:0.88940
# [53]	eval-auc:0.85864	train-auc:0.88940
# [54]	eval-auc:0.85864	train-auc:0.88953
# [55]	eval-auc:0.86001	train-auc:0.88973
# [56]	eval-auc:0.86093	train-auc:0.88977
# [57]	eval-auc:0.86081	train-auc:0.89072
# [58]	eval-auc:0.86061	train-auc:0.89106
# [59]	eval-auc:0.86186	train-auc:0.89111
# [60]	eval-auc:0.86307	train-auc:0.89109
# [61]	eval-auc:0.86303	train-auc:0.89198
# [62]	eval-auc:0.86146	train-auc:0.89227
# [63]	eval-auc:0.86444	train-auc:0.89380
# [64]	eval-auc:0.86492	train-auc:0.89423
# [65]	eval-auc:0.86524	train-auc:0.89451
# [66]	eval-auc:0.86645	train-auc:0.89587
# [67]	eval-auc:0.86718	train-auc:0.89613
# [68]	eval-auc:0.86686	train-auc:0.89590
# [69]	eval-auc:0.86669	train-auc:0.89639
# [70]	eval-auc:0.86726	train-auc:0.89682
# [71]	eval-auc:0.86778	train-auc:0.89680
# [72]	eval-auc:0.86830	train-auc:0.89689
# [73]	eval-auc:0.86883	train-auc:0.89726
# [74]	eval-auc:0.87072	train-auc:0.89786
# [75]	eval-auc:0.87060	train-auc:0.89823
# [76]	eval-auc:0.87201	train-auc:0.89858
# [77]	eval-auc:0.87169	train-auc:0.89918
# [78]	eval-auc:0.87161	train-auc:0.89939
# [79]	eval-auc:0.87294	train-auc:0.89999
# [80]	eval-auc:0.87173	train-auc:0.90008
# [81]	eval-auc:0.87217	train-auc:0.90041
# [82]	eval-auc:0.87245	train-auc:0.90066
# [83]	eval-auc:0.87141	train-auc:0.90076
# [84]	eval-auc:0.87145	train-auc:0.90072
# [85]	eval-auc:0.87245	train-auc:0.90114
# [86]	eval-auc:0.87229	train-auc:0.90142
# [87]	eval-auc:0.87245	train-auc:0.90165
# [88]	eval-auc:0.87229	train-auc:0.90145
# [89]	eval-auc:0.87318	train-auc:0.90184
# [90]	eval-auc:0.87205	train-auc:0.90181
# [91]	eval-auc:0.87225	train-auc:0.90219
# [92]	eval-auc:0.87298	train-auc:0.90215
# [93]	eval-auc:0.87390	train-auc:0.90241
# [94]	eval-auc:0.87277	train-auc:0.90272
# [95]	eval-auc:0.87426	train-auc:0.90319
# [96]	eval-auc:0.87463	train-auc:0.90321
# [97]	eval-auc:0.87334	train-auc:0.90324
# [98]	eval-auc:0.87503	train-auc:0.90373
# [99]	eval-auc:0.87519	train-auc:0.90420
# [100]	eval-auc:0.87555	train-auc:0.90426
# [101]	eval-auc:0.87592	train-auc:0.90449
# [102]	eval-auc:0.87584	train-auc:0.90478
# [103]	eval-auc:0.87592	train-auc:0.90480
# [104]	eval-auc:0.87588	train-auc:0.90477
# [105]	eval-auc:0.87579	train-auc:0.90465
# [106]	eval-auc:0.87628	train-auc:0.90470
# [107]	eval-auc:0.87579	train-auc:0.90503
# [108]	eval-auc:0.87632	train-auc:0.90502
# [109]	eval-auc:0.87567	train-auc:0.90502
# [110]	eval-auc:0.87648	train-auc:0.90523
# [111]	eval-auc:0.87612	train-auc:0.90540
# [112]	eval-auc:0.87636	train-auc:0.90535
# [113]	eval-auc:0.87692	train-auc:0.90551
# [114]	eval-auc:0.87712	train-auc:0.90554
# [115]	eval-auc:0.87845	train-auc:0.90593
# [116]	eval-auc:0.87777	train-auc:0.90592
# [117]	eval-auc:0.87801	train-auc:0.90642
# [118]	eval-auc:0.87785	train-auc:0.90668
# [119]	eval-auc:0.87753	train-auc:0.90677
# [120]	eval-auc:0.87733	train-auc:0.90694
# [121]	eval-auc:0.87801	train-auc:0.90714
# [122]	eval-auc:0.87704	train-auc:0.90727
# [123]	eval-auc:0.87777	train-auc:0.90765
# [124]	eval-auc:0.87785	train-auc:0.90778
# [125]	eval-auc:0.87708	train-auc:0.90787
# [126]	eval-auc:0.87729	train-auc:0.90783
# [127]	eval-auc:0.87680	train-auc:0.90784
# [128]	eval-auc:0.87660	train-auc:0.90810
# [129]	eval-auc:0.87600	train-auc:0.90812
# [130]	eval-auc:0.87664	train-auc:0.90824
# [131]	eval-auc:0.87696	train-auc:0.90839
# [132]	eval-auc:0.87753	train-auc:0.90866
# [133]	eval-auc:0.87716	train-auc:0.90909
# [134]	eval-auc:0.87700	train-auc:0.90914
# [135]	eval-auc:0.87737	train-auc:0.90931
# [136]	eval-auc:0.87753	train-auc:0.90915
# [137]	eval-auc:0.87833	train-auc:0.90959
# [138]	eval-auc:0.87837	train-auc:0.90989
# [139]	eval-auc:0.87789	train-auc:0.90963
# [140]	eval-auc:0.87725	train-auc:0.90981
# [141]	eval-auc:0.87680	train-auc:0.90986
# [142]	eval-auc:0.87716	train-auc:0.90995
# [143]	eval-auc:0.87592	train-auc:0.91005
# [144]	eval-auc:0.87604	train-auc:0.91012
# [145]	eval-auc:0.87575	train-auc:0.91008
# [146]	eval-auc:0.87725	train-auc:0.91038
# [147]	eval-auc:0.87781	train-auc:0.91023
# [148]	eval-auc:0.87845	train-auc:0.91051
# [149]	eval-auc:0.87853	train-auc:0.91039
# [150]	eval-auc:0.87769	train-auc:0.91038
# [151]	eval-auc:0.87773	train-auc:0.91078
# [152]	eval-auc:0.87757	train-auc:0.91082
# [153]	eval-auc:0.87777	train-auc:0.91086
# [154]	eval-auc:0.87781	train-auc:0.91090
# [155]	eval-auc:0.87725	train-auc:0.91104
# [156]	eval-auc:0.87620	train-auc:0.91111
# [157]	eval-auc:0.87636	train-auc:0.91113
# [158]	eval-auc:0.87535	train-auc:0.91103
# [159]	eval-auc:0.87559	train-auc:0.91133
# [160]	eval-auc:0.87620	train-auc:0.91148
# [161]	eval-auc:0.87543	train-auc:0.91160
# [162]	eval-auc:0.87584	train-auc:0.91168
# [163]	eval-auc:0.87563	train-auc:0.91166
# [164]	eval-auc:0.87696	train-auc:0.91174
# [165]	eval-auc:0.87757	train-auc:0.91160
# [166]	eval-auc:0.87708	train-auc:0.91190
# [167]	eval-auc:0.87684	train-auc:0.91195
# [168]	eval-auc:0.87660	train-auc:0.91186
# [169]	eval-auc:0.87704	train-auc:0.91193
# [170]	eval-auc:0.87797	train-auc:0.91189
# [171]	eval-auc:0.87817	train-auc:0.91194
# [172]	eval-auc:0.87753	train-auc:0.91188
# [173]	eval-auc:0.87741	train-auc:0.91204
# [174]	eval-auc:0.87725	train-auc:0.91222
# [175]	eval-auc:0.87769	train-auc:0.91243
# [176]	eval-auc:0.87757	train-auc:0.91267
# [177]	eval-auc:0.87700	train-auc:0.91270
# [178]	eval-auc:0.87640	train-auc:0.91285
# [179]	eval-auc:0.87555	train-auc:0.91301
# [180]	eval-auc:0.87555	train-auc:0.91307
# [181]	eval-auc:0.87584	train-auc:0.91342
# [182]	eval-auc:0.87700	train-auc:0.91337
# [183]	eval-auc:0.87696	train-auc:0.91341
# [184]	eval-auc:0.87712	train-auc:0.91365
# [185]	eval-auc:0.87684	train-auc:0.91373
# [186]	eval-auc:0.87725	train-auc:0.91371
# [187]	eval-auc:0.87716	train-auc:0.91381
# [188]	eval-auc:0.87809	train-auc:0.91403
# [189]	eval-auc:0.87841	train-auc:0.91406
# [190]	eval-auc:0.87741	train-auc:0.91403
# [191]	eval-auc:0.87700	train-auc:0.91399
# [192]	eval-auc:0.87757	train-auc:0.91404
# [193]	eval-auc:0.87801	train-auc:0.91405
# [194]	eval-auc:0.87769	train-auc:0.91422
# [195]	eval-auc:0.87769	train-auc:0.91431
# [196]	eval-auc:0.87813	train-auc:0.91454
# [197]	eval-auc:0.87845	train-auc:0.91456
# [198]	eval-auc:0.87898	train-auc:0.91437
# [199]	eval-auc:0.87829	train-auc:0.91437
# [200]	eval-auc:0.87837	train-auc:0.91438
# [201]	eval-auc:0.87813	train-auc:0.91438
# [202]	eval-auc:0.87773	train-auc:0.91439
# [203]	eval-auc:0.87733	train-auc:0.91457
# [204]	eval-auc:0.87733	train-auc:0.91456
# [205]	eval-auc:0.87793	train-auc:0.91460
# [206]	eval-auc:0.87692	train-auc:0.91458
# [207]	eval-auc:0.87688	train-auc:0.91463
# [208]	eval-auc:0.87749	train-auc:0.91471
# [209]	eval-auc:0.87801	train-auc:0.91495
# [210]	eval-auc:0.87813	train-auc:0.91514
# [211]	eval-auc:0.87817	train-auc:0.91508
# [212]	eval-auc:0.87865	train-auc:0.91524
# [213]	eval-auc:0.87890	train-auc:0.91523
# [214]	eval-auc:0.87914	train-auc:0.91532
# [215]	eval-auc:0.87946	train-auc:0.91545
# [216]	eval-auc:0.87954	train-auc:0.91555
# [217]	eval-auc:0.87970	train-auc:0.91558
# [218]	eval-auc:0.87950	train-auc:0.91563
# [219]	eval-auc:0.88051	train-auc:0.91575
# [220]	eval-auc:0.87954	train-auc:0.91583
# [221]	eval-auc:0.87970	train-auc:0.91601
# [222]	eval-auc:0.87986	train-auc:0.91610
# [223]	eval-auc:0.88047	train-auc:0.91609
# [224]	eval-auc:0.88095	train-auc:0.91618
# [225]	eval-auc:0.88103	train-auc:0.91622
# [226]	eval-auc:0.88043	train-auc:0.91620
# [227]	eval-auc:0.88075	train-auc:0.91615
# [228]	eval-auc:0.87974	train-auc:0.91619
# [229]	eval-auc:0.88103	train-auc:0.91598
# [230]	eval-auc:0.88043	train-auc:0.91611
# [231]	eval-auc:0.87922	train-auc:0.91614
# [232]	eval-auc:0.87886	train-auc:0.91625
# [233]	eval-auc:0.87946	train-auc:0.91642
# [234]	eval-auc:0.87958	train-auc:0.91648
# [235]	eval-auc:0.87902	train-auc:0.91639
# [236]	eval-auc:0.87902	train-auc:0.91627
# [237]	eval-auc:0.87918	train-auc:0.91637
# [238]	eval-auc:0.87970	train-auc:0.91652
# [239]	eval-auc:0.87934	train-auc:0.91662
# [240]	eval-auc:0.87938	train-auc:0.91671
# [241]	eval-auc:0.87946	train-auc:0.91678
# [242]	eval-auc:0.87958	train-auc:0.91684
# [243]	eval-auc:0.88095	train-auc:0.91693
# [244]	eval-auc:0.88123	train-auc:0.91699
# [245]	eval-auc:0.88163	train-auc:0.91712
# [246]	eval-auc:0.88184	train-auc:0.91711
# [247]	eval-auc:0.88131	train-auc:0.91712
# [248]	eval-auc:0.88075	train-auc:0.91714
# [249]	eval-auc:0.87994	train-auc:0.91729
# [250]	eval-auc:0.87934	train-auc:0.91727
# [251]	eval-auc:0.88002	train-auc:0.91721
# [252]	eval-auc:0.87982	train-auc:0.91715
# [253]	eval-auc:0.87942	train-auc:0.91702
# [254]	eval-auc:0.87882	train-auc:0.91695
# [255]	eval-auc:0.87970	train-auc:0.91701
# [256]	eval-auc:0.87942	train-auc:0.91708
# [257]	eval-auc:0.87950	train-auc:0.91708
# [258]	eval-auc:0.87942	train-auc:0.91710
# [259]	eval-auc:0.87906	train-auc:0.91707
# [260]	eval-auc:0.87986	train-auc:0.91730
# [261]	eval-auc:0.87986	train-auc:0.91737
# [262]	eval-auc:0.87974	train-auc:0.91746
# [263]	eval-auc:0.87978	train-auc:0.91755
# [264]	eval-auc:0.87986	train-auc:0.91747
# [265]	eval-auc:0.88047	train-auc:0.91770
# [266]	eval-auc:0.87998	train-auc:0.91795
# [267]	eval-auc:0.88047	train-auc:0.91792
# [268]	eval-auc:0.88075	train-auc:0.91792
# [269]	eval-auc:0.88035	train-auc:0.91798
# [270]	eval-auc:0.88055	train-auc:0.91794
# [271]	eval-auc:0.88103	train-auc:0.91806
# [272]	eval-auc:0.88002	train-auc:0.91827
# [273]	eval-auc:0.88035	train-auc:0.91831
# [274]	eval-auc:0.88063	train-auc:0.91823
# [275]	eval-auc:0.88043	train-auc:0.91833
# [276]	eval-auc:0.88059	train-auc:0.91828
# [277]	eval-auc:0.88091	train-auc:0.91826
# [278]	eval-auc:0.88115	train-auc:0.91834
# [279]	eval-auc:0.88127	train-auc:0.91836
# [280]	eval-auc:0.88176	train-auc:0.91855
# [281]	eval-auc:0.88131	train-auc:0.91856
# [282]	eval-auc:0.88091	train-auc:0.91857
# [283]	eval-auc:0.88123	train-auc:0.91861
# [284]	eval-auc:0.88151	train-auc:0.91857
# [285]	eval-auc:0.88143	train-auc:0.91868
# [286]	eval-auc:0.88055	train-auc:0.91872
# [287]	eval-auc:0.88111	train-auc:0.91885
# [288]	eval-auc:0.88115	train-auc:0.91888
# [289]	eval-auc:0.88095	train-auc:0.91899
# [290]	eval-auc:0.88135	train-auc:0.91900
# [291]	eval-auc:0.88176	train-auc:0.91905
# [292]	eval-auc:0.88172	train-auc:0.91910
# [293]	eval-auc:0.88176	train-auc:0.91909
# [294]	eval-auc:0.88192	train-auc:0.91900
# [295]	eval-auc:0.88244	train-auc:0.91911
# [296]	eval-auc:0.88232	train-auc:0.91924
# [297]	eval-auc:0.88131	train-auc:0.91914
# [298]	eval-auc:0.88143	train-auc:0.91916
# [299]	eval-auc:0.88039	train-auc:0.91926

# %%
eval_akt1 = pd.DataFrame(eval_akt1).T
eval_akt1.to_csv('../../../../Desktop/binding/thesis english/Results/2-XGBoost/akt1.csv')
eval_akt1
# Out:
#          roc_auc     tn    fp    fn    tp       map  precision    recall  \
# Test    0.872686  168.0  22.0  40.0  76.0  0.812078   0.775510  0.655172
# Random  0.880387  163.0  28.0  34.0  96.0  0.860120   0.774194  0.738462
#
#         accuracy
# Test    0.797386
# Random  0.806854

# %%
eval_pi3k = {}
for i in range(len(train_list_pi3k)):
    if i == 1:
        smi = train_list_pi3k[i].rdkit
        mols = [Chem.MolFromSmiles(smi) for smi in smi]
        ECFP = [AllChem.GetMorganFingerprintAsBitVect(x,2,nBits=1024) for x in mols]
        a = np.array(ECFP)
        ECFP_smiles = a.astype(np.float32)
        train_labels = Y_train_pi3k
        dmatrix_train = xgb.DMatrix(data = ECFP_smiles,label = train_labels)
        
        smi = val_list_pi3k[i].rdkit
        mols = [Chem.MolFromSmiles(smi) for smi in smi]
        ECFP = [AllChem.GetMorganFingerprintAsBitVect(x,2,nBits=1024) for x in mols]
        a = np.array(ECFP)
        ECFP_smiles = a.astype(np.float32)
        val_labels = Y_val_pi3k
        dmatrix_val = xgb.DMatrix(data = ECFP_smiles,label = val_labels)
        del smi,mols,ECFP,a,ECFP_smiles
        
        evalist = [(dmatrix_val,'eval'),(dmatrix_train,'train')]
        model = class_xgb.build_model(dmatrix_train,evalist,True,300)
    else:
        dmatrix_train,train_labels = class_xgb.to_xgb_input(train_list_pi3k[i])
        dmatrix_val,val_labels = class_xgb.to_xgb_input(val_list_pi3k[i])
        evalist = [(dmatrix_val,'eval'),(dmatrix_train,'train')]
        model = class_xgb.build_model(dmatrix_train,evalist,True,300)
    
    y_pred_val = model.predict(dmatrix_val)
    if i == 0:
        eval_pi3k['Test'] = calculate_metrics(np.array(val_labels),y_pred_val)
    elif i == 1:
        eval_pi3k['Random'] = calculate_metrics(np.array(val_labels),y_pred_val)
# Out:
# [0]	eval-auc:0.72200	train-auc:0.70592
# [1]	eval-auc:0.68301	train-auc:0.74260
# [2]	eval-auc:0.69628	train-auc:0.76914
# [3]	eval-auc:0.69529	train-auc:0.78318
# [4]	eval-auc:0.73879	train-auc:0.78736
# [5]	eval-auc:0.71432	train-auc:0.80538
# [6]	eval-auc:0.72304	train-auc:0.80939
# [7]	eval-auc:0.72648	train-auc:0.81340
# [8]	eval-auc:0.74481	train-auc:0.81878
# [9]	eval-auc:0.75756	train-auc:0.82219
# [10]	eval-auc:0.76321	train-auc:0.82756
# [11]	eval-auc:0.77043	train-auc:0.83228
# [12]	eval-auc:0.76563	train-auc:0.83384
# [13]	eval-auc:0.75301	train-auc:0.83662
# [14]	eval-auc:0.76732	train-auc:0.83935
# [15]	eval-auc:0.77700	train-auc:0.84346
# [16]	eval-auc:0.77670	train-auc:0.84503
# [17]	eval-auc:0.77566	train-auc:0.84694
# [18]	eval-auc:0.77779	train-auc:0.85008
# [19]	eval-auc:0.78445	train-auc:0.85382
# [20]	eval-auc:0.78817	train-auc:0.85549
# [21]	eval-auc:0.79499	train-auc:0.85830
# [22]	eval-auc:0.79734	train-auc:0.85938
# [23]	eval-auc:0.79707	train-auc:0.86167
# [24]	eval-auc:0.79722	train-auc:0.86485
# [25]	eval-auc:0.80383	train-auc:0.86606
# [26]	eval-auc:0.80507	train-auc:0.86658
# [27]	eval-auc:0.80554	train-auc:0.86771
# [28]	eval-auc:0.80808	train-auc:0.86815
# [29]	eval-auc:0.80585	train-auc:0.86891
# [30]	eval-auc:0.80629	train-auc:0.87005
# [31]	eval-auc:0.81670	train-auc:0.87105
# [32]	eval-auc:0.81877	train-auc:0.87167
# [33]	eval-auc:0.81482	train-auc:0.87357
# [34]	eval-auc:0.81565	train-auc:0.87412
# [35]	eval-auc:0.81901	train-auc:0.87522
# [36]	eval-auc:0.81733	train-auc:0.87597
# [37]	eval-auc:0.82067	train-auc:0.87679
# [38]	eval-auc:0.82025	train-auc:0.87769
# [39]	eval-auc:0.81904	train-auc:0.87866
# [40]	eval-auc:0.82318	train-auc:0.87957
# [41]	eval-auc:0.82233	train-auc:0.87995
# [42]	eval-auc:0.82072	train-auc:0.88014
# [43]	eval-auc:0.82340	train-auc:0.88097
# [44]	eval-auc:0.82458	train-auc:0.88148
# [45]	eval-auc:0.82677	train-auc:0.88157
# [46]	eval-auc:0.82731	train-auc:0.88214
# [47]	eval-auc:0.82554	train-auc:0.88249
# [48]	eval-auc:0.82558	train-auc:0.88308
# [49]	eval-auc:0.82035	train-auc:0.88368
# [50]	eval-auc:0.82204	train-auc:0.88418
# [51]	eval-auc:0.82892	train-auc:0.88486
# [52]	eval-auc:0.82485	train-auc:0.88474
# [53]	eval-auc:0.82391	train-auc:0.88545
# [54]	eval-auc:0.82280	train-auc:0.88614
# [55]	eval-auc:0.82494	train-auc:0.88643
# [56]	eval-auc:0.82181	train-auc:0.88677
# [57]	eval-auc:0.82651	train-auc:0.88791
# [58]	eval-auc:0.82575	train-auc:0.88841
# [59]	eval-auc:0.82652	train-auc:0.88873
# [60]	eval-auc:0.82508	train-auc:0.88897
# [61]	eval-auc:0.82582	train-auc:0.89049
# [62]	eval-auc:0.82922	train-auc:0.89159
# [63]	eval-auc:0.82609	train-auc:0.89232
# [64]	eval-auc:0.82849	train-auc:0.89263
# [65]	eval-auc:0.82595	train-auc:0.89321
# [66]	eval-auc:0.82934	train-auc:0.89371
# [67]	eval-auc:0.82584	train-auc:0.89428
# [68]	eval-auc:0.82865	train-auc:0.89450
# [69]	eval-auc:0.82720	train-auc:0.89449
# [70]	eval-auc:0.83075	train-auc:0.89489
# [71]	eval-auc:0.82995	train-auc:0.89517
# [72]	eval-auc:0.83241	train-auc:0.89561
# [73]	eval-auc:0.83249	train-auc:0.89573
# [74]	eval-auc:0.83238	train-auc:0.89582
# [75]	eval-auc:0.83307	train-auc:0.89596
# [76]	eval-auc:0.83368	train-auc:0.89640
# [77]	eval-auc:0.83308	train-auc:0.89634
# [78]	eval-auc:0.83306	train-auc:0.89655
# [79]	eval-auc:0.83490	train-auc:0.89716
# [80]	eval-auc:0.83413	train-auc:0.89751
# [81]	eval-auc:0.83544	train-auc:0.89805
# [82]	eval-auc:0.83613	train-auc:0.89822
# [83]	eval-auc:0.83705	train-auc:0.89859
# [84]	eval-auc:0.83537	train-auc:0.89885
# [85]	eval-auc:0.83428	train-auc:0.89949
# [86]	eval-auc:0.83512	train-auc:0.90024
# [87]	eval-auc:0.83453	train-auc:0.90049
# [88]	eval-auc:0.83428	train-auc:0.90087
# [89]	eval-auc:0.83634	train-auc:0.90098
# [90]	eval-auc:0.83661	train-auc:0.90170
# [91]	eval-auc:0.83458	train-auc:0.90200
# [92]	eval-auc:0.83296	train-auc:0.90206
# [93]	eval-auc:0.83532	train-auc:0.90207
# [94]	eval-auc:0.83264	train-auc:0.90273
# [95]	eval-auc:0.83276	train-auc:0.90303
# [96]	eval-auc:0.83571	train-auc:0.90363
# [97]	eval-auc:0.83689	train-auc:0.90412
# [98]	eval-auc:0.83593	train-auc:0.90431
# [99]	eval-auc:0.83625	train-auc:0.90414
# [100]	eval-auc:0.84069	train-auc:0.90470
# [101]	eval-auc:0.84034	train-auc:0.90505
# [102]	eval-auc:0.83843	train-auc:0.90521
# [103]	eval-auc:0.83918	train-auc:0.90557
# [104]	eval-auc:0.84265	train-auc:0.90567
# [105]	eval-auc:0.84415	train-auc:0.90593
# [106]	eval-auc:0.84384	train-auc:0.90606
# [107]	eval-auc:0.84342	train-auc:0.90635
# [108]	eval-auc:0.84461	train-auc:0.90664
# [109]	eval-auc:0.84495	train-auc:0.90708
# [110]	eval-auc:0.84710	train-auc:0.90729
# [111]	eval-auc:0.84754	train-auc:0.90747
# [112]	eval-auc:0.85002	train-auc:0.90776
# [113]	eval-auc:0.84878	train-auc:0.90773
# [114]	eval-auc:0.84955	train-auc:0.90813
# [115]	eval-auc:0.85145	train-auc:0.90802
# [116]	eval-auc:0.85112	train-auc:0.90822
# [117]	eval-auc:0.85184	train-auc:0.90938
# [118]	eval-auc:0.85120	train-auc:0.90938
# [119]	eval-auc:0.85144	train-auc:0.90948
# [120]	eval-auc:0.84919	train-auc:0.90989
# [121]	eval-auc:0.85118	train-auc:0.91039
# [122]	eval-auc:0.84962	train-auc:0.91019
# [123]	eval-auc:0.85057	train-auc:0.91027
# [124]	eval-auc:0.85076	train-auc:0.91051
# [125]	eval-auc:0.84962	train-auc:0.91084
# [126]	eval-auc:0.85076	train-auc:0.91103
# [127]	eval-auc:0.85177	train-auc:0.91131
# [128]	eval-auc:0.85159	train-auc:0.91159
# [129]	eval-auc:0.85013	train-auc:0.91171
# [130]	eval-auc:0.84867	train-auc:0.91171
# [131]	eval-auc:0.84889	train-auc:0.91212
# [132]	eval-auc:0.84789	train-auc:0.91225
# [133]	eval-auc:0.84836	train-auc:0.91232
# [134]	eval-auc:0.85018	train-auc:0.91251
# [135]	eval-auc:0.84936	train-auc:0.91253
# [136]	eval-auc:0.85008	train-auc:0.91268
# [137]	eval-auc:0.85127	train-auc:0.91307
# [138]	eval-auc:0.85133	train-auc:0.91317
# [139]	eval-auc:0.85111	train-auc:0.91313
# [140]	eval-auc:0.85188	train-auc:0.91304
# [141]	eval-auc:0.85091	train-auc:0.91342
# [142]	eval-auc:0.85309	train-auc:0.91366
# [143]	eval-auc:0.85392	train-auc:0.91378
# [144]	eval-auc:0.85218	train-auc:0.91401
# [145]	eval-auc:0.85196	train-auc:0.91391
# [146]	eval-auc:0.85372	train-auc:0.91466
# [147]	eval-auc:0.85367	train-auc:0.91479
# [148]	eval-auc:0.85375	train-auc:0.91514
# [149]	eval-auc:0.85380	train-auc:0.91523
# [150]	eval-auc:0.85174	train-auc:0.91576
# [151]	eval-auc:0.85290	train-auc:0.91615
# [152]	eval-auc:0.85176	train-auc:0.91627
# [153]	eval-auc:0.85250	train-auc:0.91641
# [154]	eval-auc:0.85206	train-auc:0.91680
# [155]	eval-auc:0.85295	train-auc:0.91665
# [156]	eval-auc:0.85493	train-auc:0.91683
# [157]	eval-auc:0.85372	train-auc:0.91701
# [158]	eval-auc:0.85562	train-auc:0.91772
# [159]	eval-auc:0.85607	train-auc:0.91800
# [160]	eval-auc:0.85672	train-auc:0.91828
# [161]	eval-auc:0.85446	train-auc:0.91832
# [162]	eval-auc:0.85297	train-auc:0.91809
# [163]	eval-auc:0.85469	train-auc:0.91824
# [164]	eval-auc:0.85648	train-auc:0.91814
# [165]	eval-auc:0.85573	train-auc:0.91827
# [166]	eval-auc:0.85665	train-auc:0.91857
# [167]	eval-auc:0.85750	train-auc:0.91872
# [168]	eval-auc:0.85573	train-auc:0.91864
# [169]	eval-auc:0.85421	train-auc:0.91881
# [170]	eval-auc:0.85289	train-auc:0.91884
# [171]	eval-auc:0.85417	train-auc:0.91892
# [172]	eval-auc:0.85417	train-auc:0.91895
# [173]	eval-auc:0.85540	train-auc:0.91897
# [174]	eval-auc:0.85808	train-auc:0.91917
# [175]	eval-auc:0.85672	train-auc:0.91929
# [176]	eval-auc:0.85810	train-auc:0.91932
# [177]	eval-auc:0.85880	train-auc:0.91945
# [178]	eval-auc:0.85785	train-auc:0.91960
# [179]	eval-auc:0.85815	train-auc:0.91968
# [180]	eval-auc:0.85788	train-auc:0.91972
# [181]	eval-auc:0.85924	train-auc:0.92022
# [182]	eval-auc:0.85869	train-auc:0.92020
# [183]	eval-auc:0.85884	train-auc:0.92011
# [184]	eval-auc:0.85863	train-auc:0.92029
# [185]	eval-auc:0.85941	train-auc:0.92032
# [186]	eval-auc:0.86189	train-auc:0.92066
# [187]	eval-auc:0.86206	train-auc:0.92063
# [188]	eval-auc:0.86142	train-auc:0.92072
# [189]	eval-auc:0.86153	train-auc:0.92102
# [190]	eval-auc:0.86253	train-auc:0.92105
# [191]	eval-auc:0.86350	train-auc:0.92133
# [192]	eval-auc:0.86033	train-auc:0.92152
# [193]	eval-auc:0.86071	train-auc:0.92179
# [194]	eval-auc:0.85986	train-auc:0.92188
# [195]	eval-auc:0.86154	train-auc:0.92202
# [196]	eval-auc:0.86184	train-auc:0.92204
# [197]	eval-auc:0.86060	train-auc:0.92218
# [198]	eval-auc:0.86120	train-auc:0.92215
# [199]	eval-auc:0.86131	train-auc:0.92221
# [200]	eval-auc:0.86234	train-auc:0.92242
# [201]	eval-auc:0.86399	train-auc:0.92246
# [202]	eval-auc:0.86474	train-auc:0.92248
# [203]	eval-auc:0.86484	train-auc:0.92273
# [204]	eval-auc:0.86407	train-auc:0.92266
# [205]	eval-auc:0.86165	train-auc:0.92294
# [206]	eval-auc:0.86214	train-auc:0.92298
# [207]	eval-auc:0.85964	train-auc:0.92307
# [208]	eval-auc:0.86035	train-auc:0.92327
# [209]	eval-auc:0.86176	train-auc:0.92366
# [210]	eval-auc:0.86229	train-auc:0.92377
# [211]	eval-auc:0.86227	train-auc:0.92380
# [212]	eval-auc:0.86188	train-auc:0.92384
# [213]	eval-auc:0.86092	train-auc:0.92397
# [214]	eval-auc:0.86199	train-auc:0.92414
# [215]	eval-auc:0.86205	train-auc:0.92434
# [216]	eval-auc:0.86132	train-auc:0.92441
# [217]	eval-auc:0.86307	train-auc:0.92464
# [218]	eval-auc:0.86268	train-auc:0.92482
# [219]	eval-auc:0.86197	train-auc:0.92489
# [220]	eval-auc:0.86332	train-auc:0.92493
# [221]	eval-auc:0.86369	train-auc:0.92509
# [222]	eval-auc:0.86287	train-auc:0.92524
# [223]	eval-auc:0.86392	train-auc:0.92541
# [224]	eval-auc:0.86310	train-auc:0.92558
# [225]	eval-auc:0.86375	train-auc:0.92568
# [226]	eval-auc:0.86383	train-auc:0.92548
# [227]	eval-auc:0.86315	train-auc:0.92552
# [228]	eval-auc:0.86394	train-auc:0.92582
# [229]	eval-auc:0.86532	train-auc:0.92588
# [230]	eval-auc:0.86442	train-auc:0.92590
# [231]	eval-auc:0.86401	train-auc:0.92599
# [232]	eval-auc:0.86519	train-auc:0.92619
# [233]	eval-auc:0.86400	train-auc:0.92638
# [234]	eval-auc:0.86351	train-auc:0.92645
# [235]	eval-auc:0.86293	train-auc:0.92660
# [236]	eval-auc:0.86183	train-auc:0.92641
# [237]	eval-auc:0.86356	train-auc:0.92674
# [238]	eval-auc:0.86216	train-auc:0.92668
# [239]	eval-auc:0.86194	train-auc:0.92678
# [240]	eval-auc:0.86083	train-auc:0.92701
# [241]	eval-auc:0.86069	train-auc:0.92711
# [242]	eval-auc:0.86072	train-auc:0.92699
# [243]	eval-auc:0.86176	train-auc:0.92699
# [244]	eval-auc:0.86306	train-auc:0.92736
# [245]	eval-auc:0.86321	train-auc:0.92737
# [246]	eval-auc:0.86274	train-auc:0.92764
# [247]	eval-auc:0.86163	train-auc:0.92786
# [248]	eval-auc:0.86263	train-auc:0.92793
# [249]	eval-auc:0.86419	train-auc:0.92797
# [250]	eval-auc:0.86317	train-auc:0.92800
# [251]	eval-auc:0.86326	train-auc:0.92802
# [252]	eval-auc:0.86246	train-auc:0.92802
# [253]	eval-auc:0.86419	train-auc:0.92815
# [254]	eval-auc:0.86365	train-auc:0.92831
# [255]	eval-auc:0.86585	train-auc:0.92850
# [256]	eval-auc:0.86478	train-auc:0.92868
# [257]	eval-auc:0.86491	train-auc:0.92862
# [258]	eval-auc:0.86547	train-auc:0.92849
# [259]	eval-auc:0.86584	train-auc:0.92862
# [260]	eval-auc:0.86728	train-auc:0.92876
# [261]	eval-auc:0.86696	train-auc:0.92878
# [262]	eval-auc:0.86686	train-auc:0.92889
# [263]	eval-auc:0.86722	train-auc:0.92908
# [264]	eval-auc:0.86756	train-auc:0.92919
# [265]	eval-auc:0.86778	train-auc:0.92929
# [266]	eval-auc:0.86701	train-auc:0.92955
# [267]	eval-auc:0.86582	train-auc:0.92983
# [268]	eval-auc:0.86486	train-auc:0.92974
# [269]	eval-auc:0.86601	train-auc:0.92982
# [270]	eval-auc:0.86613	train-auc:0.92989
# [271]	eval-auc:0.86618	train-auc:0.92993
# [272]	eval-auc:0.86612	train-auc:0.92995
# [273]	eval-auc:0.86794	train-auc:0.93004
# [274]	eval-auc:0.86822	train-auc:0.93025
# [275]	eval-auc:0.86846	train-auc:0.93036
# [276]	eval-auc:0.86817	train-auc:0.93044
# [277]	eval-auc:0.86780	train-auc:0.93059
# [278]	eval-auc:0.86726	train-auc:0.93081
# [279]	eval-auc:0.86711	train-auc:0.93086
# [280]	eval-auc:0.86670	train-auc:0.93095
# [281]	eval-auc:0.86748	train-auc:0.93109
# [282]	eval-auc:0.86808	train-auc:0.93131
# [283]	eval-auc:0.86740	train-auc:0.93130
# [284]	eval-auc:0.86724	train-auc:0.93139
# [285]	eval-auc:0.86752	train-auc:0.93139
# [286]	eval-auc:0.86826	train-auc:0.93154
# [287]	eval-auc:0.86878	train-auc:0.93155
# [288]	eval-auc:0.86893	train-auc:0.93161
# [289]	eval-auc:0.86977	train-auc:0.93171
# [290]	eval-auc:0.87080	train-auc:0.93187
# [291]	eval-auc:0.87155	train-auc:0.93183
# [292]	eval-auc:0.87036	train-auc:0.93183
# [293]	eval-auc:0.87063	train-auc:0.93202
# [294]	eval-auc:0.87047	train-auc:0.93203
# [295]	eval-auc:0.86984	train-auc:0.93205
# [296]	eval-auc:0.86983	train-auc:0.93204
# [297]	eval-auc:0.86953	train-auc:0.93221
# [298]	eval-auc:0.86920	train-auc:0.93246
# [299]	eval-auc:0.86930	train-auc:0.93259
# [0]	eval-auc:0.67778	train-auc:0.68428
# [1]	eval-auc:0.71804	train-auc:0.72639
# [2]	eval-auc:0.75590	train-auc:0.75669
# [3]	eval-auc:0.78015	train-auc:0.78103
# [4]	eval-auc:0.78422	train-auc:0.79244
# [5]	eval-auc:0.78964	train-auc:0.80253
# [6]	eval-auc:0.79312	train-auc:0.80940
# [7]	eval-auc:0.79455	train-auc:0.81269
# [8]	eval-auc:0.80200	train-auc:0.81736
# [9]	eval-auc:0.80976	train-auc:0.82532
# [10]	eval-auc:0.80845	train-auc:0.82708
# [11]	eval-auc:0.81364	train-auc:0.83351
# [12]	eval-auc:0.82405	train-auc:0.84172
# [13]	eval-auc:0.82518	train-auc:0.84459
# [14]	eval-auc:0.82743	train-auc:0.84730
# [15]	eval-auc:0.82883	train-auc:0.84900
# [16]	eval-auc:0.83150	train-auc:0.85056
# [17]	eval-auc:0.83198	train-auc:0.85347
# [18]	eval-auc:0.83582	train-auc:0.85631
# [19]	eval-auc:0.83755	train-auc:0.85764
# [20]	eval-auc:0.83886	train-auc:0.85968
# [21]	eval-auc:0.84008	train-auc:0.86067
# [22]	eval-auc:0.84051	train-auc:0.86137
# [23]	eval-auc:0.84183	train-auc:0.86389
# [24]	eval-auc:0.84418	train-auc:0.86393
# [25]	eval-auc:0.84476	train-auc:0.86534
# [26]	eval-auc:0.84422	train-auc:0.86739
# [27]	eval-auc:0.84504	train-auc:0.86822
# [28]	eval-auc:0.84862	train-auc:0.87075
# [29]	eval-auc:0.85027	train-auc:0.87127
# [30]	eval-auc:0.85026	train-auc:0.87200
# [31]	eval-auc:0.84982	train-auc:0.87238
# [32]	eval-auc:0.85045	train-auc:0.87269
# [33]	eval-auc:0.84932	train-auc:0.87412
# [34]	eval-auc:0.85032	train-auc:0.87542
# [35]	eval-auc:0.85096	train-auc:0.87579
# [36]	eval-auc:0.85090	train-auc:0.87640
# [37]	eval-auc:0.85317	train-auc:0.87702
# [38]	eval-auc:0.85410	train-auc:0.87852
# [39]	eval-auc:0.85452	train-auc:0.87852
# [40]	eval-auc:0.85544	train-auc:0.87937
# [41]	eval-auc:0.85762	train-auc:0.88058
# [42]	eval-auc:0.85859	train-auc:0.88168
# [43]	eval-auc:0.85930	train-auc:0.88246
# [44]	eval-auc:0.85859	train-auc:0.88261
# [45]	eval-auc:0.86014	train-auc:0.88373
# [46]	eval-auc:0.86054	train-auc:0.88449
# [47]	eval-auc:0.86023	train-auc:0.88443
# [48]	eval-auc:0.86088	train-auc:0.88490
# [49]	eval-auc:0.86259	train-auc:0.88564
# [50]	eval-auc:0.86167	train-auc:0.88605
# [51]	eval-auc:0.86104	train-auc:0.88668
# [52]	eval-auc:0.86257	train-auc:0.88751
# [53]	eval-auc:0.86291	train-auc:0.88817
# [54]	eval-auc:0.86324	train-auc:0.88866
# [55]	eval-auc:0.86371	train-auc:0.88972
# [56]	eval-auc:0.86462	train-auc:0.88983
# [57]	eval-auc:0.86480	train-auc:0.89035
# [58]	eval-auc:0.86601	train-auc:0.89097
# [59]	eval-auc:0.86641	train-auc:0.89142
# [60]	eval-auc:0.86681	train-auc:0.89229
# [61]	eval-auc:0.86686	train-auc:0.89250
# [62]	eval-auc:0.86786	train-auc:0.89316
# [63]	eval-auc:0.86821	train-auc:0.89343
# [64]	eval-auc:0.86754	train-auc:0.89382
# [65]	eval-auc:0.86829	train-auc:0.89409
# [66]	eval-auc:0.86920	train-auc:0.89440
# [67]	eval-auc:0.86900	train-auc:0.89490
# [68]	eval-auc:0.86859	train-auc:0.89548
# [69]	eval-auc:0.86822	train-auc:0.89556
# [70]	eval-auc:0.86856	train-auc:0.89563
# [71]	eval-auc:0.86862	train-auc:0.89589
# [72]	eval-auc:0.86995	train-auc:0.89647
# [73]	eval-auc:0.86944	train-auc:0.89701
# [74]	eval-auc:0.87001	train-auc:0.89743
# [75]	eval-auc:0.86968	train-auc:0.89763
# [76]	eval-auc:0.86972	train-auc:0.89798
# [77]	eval-auc:0.87111	train-auc:0.89920
# [78]	eval-auc:0.87249	train-auc:0.89954
# [79]	eval-auc:0.87442	train-auc:0.90016
# [80]	eval-auc:0.87423	train-auc:0.90070
# [81]	eval-auc:0.87504	train-auc:0.90105
# [82]	eval-auc:0.87547	train-auc:0.90154
# [83]	eval-auc:0.87442	train-auc:0.90232
# [84]	eval-auc:0.87579	train-auc:0.90276
# [85]	eval-auc:0.87708	train-auc:0.90302
# [86]	eval-auc:0.87701	train-auc:0.90307
# [87]	eval-auc:0.87700	train-auc:0.90324
# [88]	eval-auc:0.87744	train-auc:0.90364
# [89]	eval-auc:0.87741	train-auc:0.90388
# [90]	eval-auc:0.87781	train-auc:0.90408
# [91]	eval-auc:0.87740	train-auc:0.90415
# [92]	eval-auc:0.87757	train-auc:0.90451
# [93]	eval-auc:0.87789	train-auc:0.90489
# [94]	eval-auc:0.87843	train-auc:0.90522
# [95]	eval-auc:0.87731	train-auc:0.90547
# [96]	eval-auc:0.87684	train-auc:0.90546
# [97]	eval-auc:0.87690	train-auc:0.90573
# [98]	eval-auc:0.87650	train-auc:0.90612
# [99]	eval-auc:0.87728	train-auc:0.90645
# [100]	eval-auc:0.87791	train-auc:0.90723
# [101]	eval-auc:0.87823	train-auc:0.90770
# [102]	eval-auc:0.87788	train-auc:0.90787
# [103]	eval-auc:0.87792	train-auc:0.90817
# [104]	eval-auc:0.87713	train-auc:0.90815
# [105]	eval-auc:0.87738	train-auc:0.90840
# [106]	eval-auc:0.87724	train-auc:0.90869
# [107]	eval-auc:0.87723	train-auc:0.90856
# [108]	eval-auc:0.87717	train-auc:0.90866
# [109]	eval-auc:0.87713	train-auc:0.90901
# [110]	eval-auc:0.87713	train-auc:0.90933
# [111]	eval-auc:0.87723	train-auc:0.90949
# [112]	eval-auc:0.87796	train-auc:0.90961
# [113]	eval-auc:0.87913	train-auc:0.91026
# [114]	eval-auc:0.87993	train-auc:0.91056
# [115]	eval-auc:0.88050	train-auc:0.91077
# [116]	eval-auc:0.88037	train-auc:0.91091
# [117]	eval-auc:0.88066	train-auc:0.91124
# [118]	eval-auc:0.88077	train-auc:0.91174
# [119]	eval-auc:0.88125	train-auc:0.91204
# [120]	eval-auc:0.88188	train-auc:0.91237
# [121]	eval-auc:0.88198	train-auc:0.91252
# [122]	eval-auc:0.88317	train-auc:0.91272
# [123]	eval-auc:0.88284	train-auc:0.91282
# [124]	eval-auc:0.88321	train-auc:0.91313
# [125]	eval-auc:0.88310	train-auc:0.91329
# [126]	eval-auc:0.88337	train-auc:0.91342
# [127]	eval-auc:0.88354	train-auc:0.91360
# [128]	eval-auc:0.88378	train-auc:0.91388
# [129]	eval-auc:0.88358	train-auc:0.91397
# [130]	eval-auc:0.88460	train-auc:0.91429
# [131]	eval-auc:0.88447	train-auc:0.91429
# [132]	eval-auc:0.88428	train-auc:0.91437
# [133]	eval-auc:0.88497	train-auc:0.91463
# [134]	eval-auc:0.88542	train-auc:0.91458
# [135]	eval-auc:0.88581	train-auc:0.91499
# [136]	eval-auc:0.88544	train-auc:0.91509
# [137]	eval-auc:0.88515	train-auc:0.91530
# [138]	eval-auc:0.88612	train-auc:0.91541
# [139]	eval-auc:0.88643	train-auc:0.91559
# [140]	eval-auc:0.88584	train-auc:0.91593
# [141]	eval-auc:0.88650	train-auc:0.91654
# [142]	eval-auc:0.88605	train-auc:0.91645
# [143]	eval-auc:0.88603	train-auc:0.91660
# [144]	eval-auc:0.88633	train-auc:0.91707
# [145]	eval-auc:0.88698	train-auc:0.91742
# [146]	eval-auc:0.88637	train-auc:0.91736
# [147]	eval-auc:0.88690	train-auc:0.91748
# [148]	eval-auc:0.88672	train-auc:0.91759
# [149]	eval-auc:0.88694	train-auc:0.91756
# [150]	eval-auc:0.88612	train-auc:0.91802
# [151]	eval-auc:0.88659	train-auc:0.91843
# [152]	eval-auc:0.88721	train-auc:0.91871
# [153]	eval-auc:0.88748	train-auc:0.91891
# [154]	eval-auc:0.88721	train-auc:0.91910
# [155]	eval-auc:0.88718	train-auc:0.91916
# [156]	eval-auc:0.88711	train-auc:0.91923
# [157]	eval-auc:0.88663	train-auc:0.91943
# [158]	eval-auc:0.88694	train-auc:0.91972
# [159]	eval-auc:0.88696	train-auc:0.91985
# [160]	eval-auc:0.88744	train-auc:0.91992
# [161]	eval-auc:0.88707	train-auc:0.91988
# [162]	eval-auc:0.88754	train-auc:0.92007
# [163]	eval-auc:0.88803	train-auc:0.92033
# [164]	eval-auc:0.88812	train-auc:0.92031
# [165]	eval-auc:0.88849	train-auc:0.92047
# [166]	eval-auc:0.88906	train-auc:0.92049
# [167]	eval-auc:0.88937	train-auc:0.92062
# [168]	eval-auc:0.88914	train-auc:0.92055
# [169]	eval-auc:0.88972	train-auc:0.92086
# [170]	eval-auc:0.89081	train-auc:0.92109
# [171]	eval-auc:0.89081	train-auc:0.92104
# [172]	eval-auc:0.89159	train-auc:0.92141
# [173]	eval-auc:0.89174	train-auc:0.92157
# [174]	eval-auc:0.89191	train-auc:0.92163
# [175]	eval-auc:0.89208	train-auc:0.92218
# [176]	eval-auc:0.89147	train-auc:0.92242
# [177]	eval-auc:0.89162	train-auc:0.92267
# [178]	eval-auc:0.89167	train-auc:0.92286
# [179]	eval-auc:0.89165	train-auc:0.92318
# [180]	eval-auc:0.89168	train-auc:0.92344
# [181]	eval-auc:0.89120	train-auc:0.92361
# [182]	eval-auc:0.89158	train-auc:0.92374
# [183]	eval-auc:0.89171	train-auc:0.92386
# [184]	eval-auc:0.89203	train-auc:0.92403
# [185]	eval-auc:0.89201	train-auc:0.92422
# [186]	eval-auc:0.89233	train-auc:0.92412
# [187]	eval-auc:0.89181	train-auc:0.92404
# [188]	eval-auc:0.89228	train-auc:0.92401
# [189]	eval-auc:0.89286	train-auc:0.92406
# [190]	eval-auc:0.89316	train-auc:0.92417
# [191]	eval-auc:0.89297	train-auc:0.92406
# [192]	eval-auc:0.89335	train-auc:0.92414
# [193]	eval-auc:0.89276	train-auc:0.92406
# [194]	eval-auc:0.89257	train-auc:0.92432
# [195]	eval-auc:0.89222	train-auc:0.92445
# [196]	eval-auc:0.89216	train-auc:0.92446
# [197]	eval-auc:0.89229	train-auc:0.92458
# [198]	eval-auc:0.89342	train-auc:0.92498
# [199]	eval-auc:0.89367	train-auc:0.92505
# [200]	eval-auc:0.89436	train-auc:0.92535
# [201]	eval-auc:0.89453	train-auc:0.92556
# [202]	eval-auc:0.89439	train-auc:0.92578
# [203]	eval-auc:0.89418	train-auc:0.92630
# [204]	eval-auc:0.89368	train-auc:0.92637
# [205]	eval-auc:0.89429	train-auc:0.92664
# [206]	eval-auc:0.89462	train-auc:0.92673
# [207]	eval-auc:0.89453	train-auc:0.92680
# [208]	eval-auc:0.89497	train-auc:0.92709
# [209]	eval-auc:0.89411	train-auc:0.92721
# [210]	eval-auc:0.89457	train-auc:0.92732
# [211]	eval-auc:0.89445	train-auc:0.92740
# [212]	eval-auc:0.89389	train-auc:0.92754
# [213]	eval-auc:0.89430	train-auc:0.92754
# [214]	eval-auc:0.89386	train-auc:0.92772
# [215]	eval-auc:0.89357	train-auc:0.92779
# [216]	eval-auc:0.89352	train-auc:0.92785
# [217]	eval-auc:0.89352	train-auc:0.92775
# [218]	eval-auc:0.89433	train-auc:0.92787
# [219]	eval-auc:0.89403	train-auc:0.92803
# [220]	eval-auc:0.89396	train-auc:0.92815
# [221]	eval-auc:0.89420	train-auc:0.92838
# [222]	eval-auc:0.89459	train-auc:0.92848
# [223]	eval-auc:0.89430	train-auc:0.92853
# [224]	eval-auc:0.89474	train-auc:0.92869
# [225]	eval-auc:0.89493	train-auc:0.92871
# [226]	eval-auc:0.89460	train-auc:0.92870
# [227]	eval-auc:0.89521	train-auc:0.92879
# [228]	eval-auc:0.89533	train-auc:0.92891
# [229]	eval-auc:0.89528	train-auc:0.92899
# [230]	eval-auc:0.89518	train-auc:0.92903
# [231]	eval-auc:0.89547	train-auc:0.92905
# [232]	eval-auc:0.89496	train-auc:0.92915
# [233]	eval-auc:0.89464	train-auc:0.92932
# [234]	eval-auc:0.89450	train-auc:0.92952
# [235]	eval-auc:0.89540	train-auc:0.92967
# [236]	eval-auc:0.89579	train-auc:0.92973
# [237]	eval-auc:0.89483	train-auc:0.92986
# [238]	eval-auc:0.89517	train-auc:0.92985
# [239]	eval-auc:0.89531	train-auc:0.93004
# [240]	eval-auc:0.89572	train-auc:0.93011
# [241]	eval-auc:0.89594	train-auc:0.93027
# [242]	eval-auc:0.89584	train-auc:0.93040
# [243]	eval-auc:0.89565	train-auc:0.93037
# [244]	eval-auc:0.89585	train-auc:0.93046
# [245]	eval-auc:0.89608	train-auc:0.93040
# [246]	eval-auc:0.89594	train-auc:0.93046
# [247]	eval-auc:0.89552	train-auc:0.93059
# [248]	eval-auc:0.89594	train-auc:0.93056
# [249]	eval-auc:0.89633	train-auc:0.93077
# [250]	eval-auc:0.89649	train-auc:0.93078
# [251]	eval-auc:0.89672	train-auc:0.93071
# [252]	eval-auc:0.89662	train-auc:0.93085
# [253]	eval-auc:0.89686	train-auc:0.93098
# [254]	eval-auc:0.89740	train-auc:0.93124
# [255]	eval-auc:0.89816	train-auc:0.93138
# [256]	eval-auc:0.89794	train-auc:0.93154
# [257]	eval-auc:0.89783	train-auc:0.93143
# [258]	eval-auc:0.89852	train-auc:0.93156
# [259]	eval-auc:0.89884	train-auc:0.93159
# [260]	eval-auc:0.89894	train-auc:0.93180
# [261]	eval-auc:0.89875	train-auc:0.93182
# [262]	eval-auc:0.89884	train-auc:0.93187
# [263]	eval-auc:0.89892	train-auc:0.93191
# [264]	eval-auc:0.89903	train-auc:0.93192
# [265]	eval-auc:0.89868	train-auc:0.93217
# [266]	eval-auc:0.89918	train-auc:0.93232
# [267]	eval-auc:0.89922	train-auc:0.93241
# [268]	eval-auc:0.89901	train-auc:0.93245
# [269]	eval-auc:0.89956	train-auc:0.93251
# [270]	eval-auc:0.89925	train-auc:0.93239
# [271]	eval-auc:0.89935	train-auc:0.93247
# [272]	eval-auc:0.89882	train-auc:0.93254
# [273]	eval-auc:0.89899	train-auc:0.93262
# [274]	eval-auc:0.89898	train-auc:0.93267
# [275]	eval-auc:0.89929	train-auc:0.93286
# [276]	eval-auc:0.89976	train-auc:0.93281
# [277]	eval-auc:0.90013	train-auc:0.93286
# [278]	eval-auc:0.90038	train-auc:0.93291
# [279]	eval-auc:0.90006	train-auc:0.93310
# [280]	eval-auc:0.90027	train-auc:0.93309
# [281]	eval-auc:0.90082	train-auc:0.93311
# [282]	eval-auc:0.90065	train-auc:0.93326
# [283]	eval-auc:0.90030	train-auc:0.93320
# [284]	eval-auc:0.90028	train-auc:0.93322
# [285]	eval-auc:0.90003	train-auc:0.93326
# [286]	eval-auc:0.90045	train-auc:0.93344
# [287]	eval-auc:0.90027	train-auc:0.93339
# [288]	eval-auc:0.90001	train-auc:0.93348
# [289]	eval-auc:0.89943	train-auc:0.93350
# [290]	eval-auc:0.90004	train-auc:0.93367
# [291]	eval-auc:0.89962	train-auc:0.93379
# [292]	eval-auc:0.89943	train-auc:0.93398
# [293]	eval-auc:0.89998	train-auc:0.93394
# [294]	eval-auc:0.89957	train-auc:0.93391
# [295]	eval-auc:0.90038	train-auc:0.93415
# [296]	eval-auc:0.90084	train-auc:0.93420
# [297]	eval-auc:0.90045	train-auc:0.93409
# [298]	eval-auc:0.90033	train-auc:0.93418
# [299]	eval-auc:0.90069	train-auc:0.93427

# %%
eval_pi3k = pd.DataFrame(eval_pi3k).T
eval_pi3k.to_csv('../../../../Desktop/binding/thesis english/Results/2-XGBoost/pi3k.csv')
eval_pi3k
# Out:
#          roc_auc     tn    fp    fn     tp       map  precision    recall  \
# Test    0.869295  315.0  45.0  66.0  111.0  0.739396   0.711538  0.627119
# Random  0.900694  334.0  43.0  49.0  138.0  0.828438   0.762431  0.737968
#
#         accuracy
# Test    0.793296
# Random  0.836879
