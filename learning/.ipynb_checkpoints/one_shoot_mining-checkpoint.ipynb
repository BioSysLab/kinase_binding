# %%
import pandas as pd
from keras.callbacks import History, ReduceLROnPlateau,EarlyStopping,ModelCheckpoint
import os
import numpy as np
from data_analysis import calculate_metrics, load_weights_and_evaluate
from model_builders import GCN_siam_model
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, roc_auc_score, auc, average_precision_score
#import scikitplot as skplt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
import keras.backend as K
from NGF.preprocessing import tensorise_smiles
from custom_layers.model_creator import encode_smiles, stage_creator
from keras.layers import Dense, Dropout, Input, Lambda, concatenate,Flatten
from keras.models import Model, load_model
from data_analysis import calculate_metrics
import dill
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import math_ops
from tensorflow.python.framework import dtypes
from distance_and_mask_fn import pairwise_distance,masked_maximum,masked_minimum

# %%
def triplet_loss_adapted_from_tf(y_true, y_pred):
    del y_true
    margin = 0.5
    labels = y_pred[:, :1]
    labels = tf.cast(labels, dtype='int32')
    embeddings = y_pred[:, 1:]

    ### Code from Tensorflow function [tf.contrib.losses.metric_learning.triplet_semihard_loss] starts here:
    
    # Reshape [batch_size] label tensor to a [batch_size, 1] label tensor.
    # lshape=array_ops.shape(labels)
    # assert lshape.shape == 1
    # labels = array_ops.reshape(labels, [lshape[0], 1])

    # Build pairwise squared distance matrix.
    pdist_matrix = pairwise_distance(embeddings, squared=False)
    # Build pairwise binary adjacency matrix.
    adjacency = math_ops.equal(labels, array_ops.transpose(labels))
    # Invert so we can select negatives only.
    adjacency_not = math_ops.logical_not(adjacency)

    # global batch_size  
    batch_size = array_ops.size(labels) # was 'array_ops.size(labels)'

    # Compute the mask.
    pdist_matrix_tile = array_ops.tile(pdist_matrix, [batch_size, 1])
    mask = math_ops.logical_and(
        array_ops.tile(adjacency_not, [batch_size, 1]),
        math_ops.greater(
            pdist_matrix_tile, array_ops.reshape(
                array_ops.transpose(pdist_matrix), [-1, 1])))
    mask_final = array_ops.reshape(
        math_ops.greater(
            math_ops.reduce_sum(
                math_ops.cast(mask, dtype=dtypes.float32), 1, keepdims=True),
            0.0), [batch_size, batch_size])
    mask_final = array_ops.transpose(mask_final)

    adjacency_not = math_ops.cast(adjacency_not, dtype=dtypes.float32)
    mask = math_ops.cast(mask, dtype=dtypes.float32)

    # negatives_outside: smallest D_an where D_an > D_ap.
    negatives_outside = array_ops.reshape(
        masked_minimum(pdist_matrix_tile, mask), [batch_size, batch_size])
    negatives_outside = array_ops.transpose(negatives_outside)

    # negatives_inside: largest D_an.
    negatives_inside = array_ops.tile(
        masked_maximum(pdist_matrix, adjacency_not), [1, batch_size])
    semi_hard_negatives = array_ops.where(
        mask_final, negatives_outside, negatives_inside)

    loss_mat = math_ops.add(margin, pdist_matrix - semi_hard_negatives)

    mask_positives = math_ops.cast(
        adjacency, dtype=dtypes.float32) - array_ops.diag(
        array_ops.ones([batch_size]))

    # In lifted-struct, the authors multiply 0.5 for upper triangular
    #   in semihard, they take all positive pairs except the diagonal.
    num_positives = math_ops.reduce_sum(mask_positives)

    semi_hard_triplet_loss_distance = math_ops.truediv(
        math_ops.reduce_sum(
            math_ops.maximum(
                math_ops.multiply(loss_mat, mask_positives), 0.0)),
        num_positives,
        name='triplet_semihard_loss')
    
    ### Code from Tensorflow function semi-hard triplet loss ENDS here.
    return semi_hard_triplet_loss_distance

# %%
es = EarlyStopping(monitor='loss',patience=8, min_delta=0)
rlr = ReduceLROnPlateau(monitor='loss',factor=0.5, patience=4, verbose=1, min_lr=0.0000001)

# %%
model_params = {
        "num_layers" : 3,
        "max_atoms" : 70,
        "num_atom_features" : 62,
        "num_atom_features_original" : 62,
        "num_bond_features" : 6,
        "max_degree" : 5,
        "conv_width" : [int(96), int(104), int(120)],
        "fp_length" : [int(160), int(160), int(160)],
        "activ_enc" : "selu",
        "activ_dec" : "selu",
        "learning_rates" : [0.001,0.001,0.001],
        "learning_rates_fp": [0.005,0.005,0.005],
        "losses_conv" : {
                    "neighbor_output": "mean_squared_error",
                    "self_output": "mean_squared_error",
                    },
        "lossWeights" : {"neighbor_output": 1.0, "self_output": 1.0},
        "metrics" : "mse",
        "loss_fp" : "mean_squared_error",
        "enc_layer_names" : ["enc_1", "enc_2", "enc_3"],
        'callbacks' : [es,rlr],
        'adam_decay': 0.0005329142291371636,
        'beta': 5,
        'p': 0.004465204118126482,
        'dense_size' : [int(512), int(512), int(256)], 
        'dropout_rate' : [0.1, 0.1],
        'lr' : 1e-4,
        'batch_size' : int(64),
        'n_epochs' : int(35),
        'margin' : 0.5
        }

# %%
def dataframe_to_gcn_input(input_data):
        x_atoms_cold, x_bonds_cold, x_edges_cold = tensorise_smiles(input_data,
                                                                    max_degree=model_params['max_degree'],
                                                                    max_atoms=model_params['max_atoms'])
        return [x_atoms_cold, x_bonds_cold, x_edges_cold]

# %%
def build_encoder(encoder_params):
        model_enc_1 = stage_creator(encoder_params, 1, conv=True)[0]
        model_enc_2 = stage_creator(encoder_params, 2, conv=True)[0]
        model_enc_3 = stage_creator(encoder_params, 3, conv=True)[0]

        model_enc_fp_1 = stage_creator(encoder_params, 1, conv=False)[1]
        model_enc_fp_2 = stage_creator(encoder_params, 2, conv=False)[1]
        model_enc_fp_3 = stage_creator(encoder_params, 3, conv=False)[1]

        atoms, bonds, edges = encode_smiles(encoder_params["max_atoms"],
                                            encoder_params["num_atom_features"],
                                            encoder_params["max_degree"],
                                            encoder_params["num_bond_features"])

        graph_conv_1 = model_enc_1([atoms, bonds, edges])
        graph_conv_2 = model_enc_2([graph_conv_1, bonds, edges])
        graph_conv_3 = model_enc_3([graph_conv_2, bonds, edges])

        fingerprint_1 = model_enc_fp_1([graph_conv_1, bonds, edges])
        fingerprint_1 = Lambda(lambda x: K.sum(x, axis=1), output_shape=lambda s: (s[0], s[2]))(fingerprint_1)

        fingerprint_2 = model_enc_fp_2([graph_conv_2, bonds, edges])
        fingerprint_2 = Lambda(lambda x: K.sum(x, axis=1), output_shape=lambda s: (s[0], s[2]))(fingerprint_2)

        fingerprint_3 = model_enc_fp_3([graph_conv_3, bonds, edges])
        fingerprint_3 = Lambda(lambda x: K.sum(x, axis=1), output_shape=lambda s: (s[0], s[2]))(fingerprint_3)

        final_fingerprint = keras.layers.add([fingerprint_1, fingerprint_2, fingerprint_3])

        return Model([atoms, bonds, edges], [final_fingerprint])

# %%
def build_model(model_params, encoder, verbose=False):
        atoms = Input(name='atom_inputs',
                      shape=(model_params['max_atoms'], model_params['num_atom_features']), dtype='float32')
        bonds = Input(name='bond_inputs', shape=(
            model_params['max_atoms'], model_params['max_degree'], model_params['num_bond_features']),
                      dtype='float32')
        edges = Input(name='edge_inputs', shape=(model_params['max_atoms'], model_params['max_degree']),
                      dtype='int32')
        encode_drug = encoder([atoms, bonds, edges])

        # Fully connected
        FC1 = Dense(model_params["dense_size"][0], activation='relu',kernel_initializer='random_normal')(encode_drug)
        FC2 = Dropout(model_params["dropout_rate"][0])(FC1)
        FC2 = Dense(model_params["dense_size"][1], activation='relu',kernel_initializer='random_normal')(FC2)
        FC2 = Dropout(model_params["dropout_rate"][1])(FC2)
        FC2 = Dense(model_params["dense_size"][2], activation = None,kernel_initializer='random_normal')(FC2)
        
        
        embeddings = Lambda(lambda x: K.l2_normalize(x,axis=1),name = 'Embeddings')(FC2)
        #predictions = Dense(1, activation='sigmoid', kernel_initializer='random_normal',name = 'Predictions')(FC2)
        gcn_model = Model(inputs=[atoms, bonds, edges], outputs = embeddings)


        #if verbose:
         #   print('encoder')
          #  encoder.summary()
           # print('GCN_model')
        gcn_model.summary()
            
        return gcn_model

# %%
def build_mining(model_params,gcn_model):
    atoms = Input(name='atom_inputs',
                  shape=(model_params['max_atoms'], model_params['num_atom_features']), dtype='float32')
    bonds = Input(name='bond_inputs', shape=(
        model_params['max_atoms'], model_params['max_degree'], model_params['num_bond_features']),
                  dtype='float32')
    edges = Input(name='edge_inputs', shape=(model_params['max_atoms'], model_params['max_degree']),
                  dtype='int32')
    
    labels = Input(name = 'labels_inputs',shape = (1,),dtype = 'float32')
    
    encoded = gcn_model([atoms,bonds,edges])
    labels_plus_embeddings = concatenate([labels, encoded])
    
    mining_net = Model(inputs = [atoms,bonds,edges,labels],outputs = labels_plus_embeddings)
    adam = keras.optimizers.Adam(lr = model_params["lr"], 
                                 beta_1=0.9, 
                                 beta_2=0.999, 
                                 decay=0.0, 
                                 amsgrad=False)
    
    
    mining_net.compile(optimizer=adam , loss = triplet_loss_adapted_from_tf)
    mining_net.summary()
    return mining_net

# %%
target = 'p38'
base_path = f'C:/Users/tomas/Documents/GitHub/kinase_binding'

data_fpath = base_path+f'/data/{target}/data.csv'
df=pd.read_csv(data_fpath).set_index('biolab_index')

with open(base_path+f'/data/{target}/train_val_folds.pkl', "rb") as in_f:
    train_val_folds = dill.load(in_f)
with open(base_path+f'/data/{target}/train_test_folds.pkl', "rb") as in_f:
    train_test_folds = dill.load(in_f)

# %%
train = df.loc[train_val_folds[0][0]]
smiles_list = list(train.rdkit)

#Train to gcn_network
train_atoms, train_bonds, train_edges = dataframe_to_gcn_input(train['rdkit'])

Y_dummy = np.empty((train_atoms.shape[0],256+1))

# %%
encoder = build_encoder(model_params)
gcn_model = build_model(model_params,encoder)
# Out:
# LAYER 0
# LAYER 1
# LAYER 2
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# atom_inputs (InputLayer)        (None, 70, 62)       0
# __________________________________________________________________________________________________
# bond_inputs (InputLayer)        (None, 70, 5, 6)     0
# __________________________________________________________________________________________________
# edge_inputs (InputLayer)        (None, 70, 5)        0
# __________________________________________________________________________________________________
# model_10 (Model)                (None, 160)          241696      atom_inputs[0][0]
#                                                                  bond_inputs[0][0]
#                                                                  edge_inputs[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          82432       model_10[1][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          131328      dropout_2[0][0]
# __________________________________________________________________________________________________
# Embeddings (Lambda)             (None, 256)          0           dense_3[0][0]
# ==================================================================================================
# Total params: 718,112
# Trainable params: 716,512
# Non-trainable params: 1,600
# __________________________________________________________________________________________________

# %%
mining_model = build_mining(model_params,gcn_model)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# atom_inputs (InputLayer)        (None, 70, 62)       0
# __________________________________________________________________________________________________
# bond_inputs (InputLayer)        (None, 70, 5, 6)     0
# __________________________________________________________________________________________________
# edge_inputs (InputLayer)        (None, 70, 5)        0
# __________________________________________________________________________________________________
# labels_inputs (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# model_11 (Model)                (None, 256)          718112      atom_inputs[0][0]
#                                                                  bond_inputs[0][0]
#                                                                  edge_inputs[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 257)          0           labels_inputs[0][0]
#                                                                  model_11[1][0]
# ==================================================================================================
# Total params: 718,112
# Trainable params: 716,512
# Non-trainable params: 1,600
# __________________________________________________________________________________________________

# %%
es = EarlyStopping(monitor='loss',patience=15, min_delta=0)
rlr2 = ReduceLROnPlateau(monitor='loss',factor=0.5, patience=2, verbose=1, min_lr=0.000000001)

# %%
mining_model.fit([train_atoms,train_bonds,train_edges,train.Binary],Y_dummy,
                 epochs = 50,
                 batch_size = 128,
                 shuffle = True,
                 callbacks=[es,rlr2])
# Out:
# C:\Users\tomas\miniconda3\envs\binding\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/50
# 2541/2541 [==============================] - 8s 3ms/step - loss: 0.4965
# Epoch 2/50
# 2541/2541 [==============================] - 1s 310us/step - loss: 0.4958
# Epoch 3/50
# 2541/2541 [==============================] - 1s 299us/step - loss: 0.4948
# Epoch 4/50
# 2541/2541 [==============================] - 1s 312us/step - loss: 0.4910
# Epoch 5/50
# 2541/2541 [==============================] - 1s 303us/step - loss: 0.4834
# Epoch 6/50
# 2541/2541 [==============================] - 1s 310us/step - loss: 0.4764
# Epoch 7/50
# 2541/2541 [==============================] - 1s 312us/step - loss: 0.4703
# Epoch 8/50
# 2541/2541 [==============================] - 1s 299us/step - loss: 0.4637
# Epoch 9/50
# 2541/2541 [==============================] - 1s 310us/step - loss: 0.4581
# Epoch 10/50
# 2541/2541 [==============================] - 1s 308us/step - loss: 0.4513
# Epoch 11/50
# 2541/2541 [==============================] - 1s 310us/step - loss: 0.4493
# Epoch 12/50
# 2541/2541 [==============================] - 1s 311us/step - loss: 0.4397
# Epoch 13/50
# 2541/2541 [==============================] - 1s 300us/step - loss: 0.4424
# Epoch 14/50
# 2541/2541 [==============================] - 1s 312us/step - loss: 0.4355
# Epoch 15/50
# 2541/2541 [==============================] - 1s 311us/step - loss: 0.4340
# Epoch 16/50
# 2541/2541 [==============================] - 1s 303us/step - loss: 0.4308
# Epoch 17/50
# 2541/2541 [==============================] - 1s 312us/step - loss: 0.4245
# Epoch 18/50
# 2541/2541 [==============================] - 1s 298us/step - loss: 0.4208
# Epoch 19/50
# 2541/2541 [==============================] - 1s 314us/step - loss: 0.4217
# Epoch 20/50
# 2541/2541 [==============================] - 1s 313us/step - loss: 0.4208
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 21/50
# 2541/2541 [==============================] - 1s 313us/step - loss: 0.4075
# Epoch 22/50
# 2541/2541 [==============================] - 1s 310us/step - loss: 0.4044
# Epoch 23/50
# 2541/2541 [==============================] - 1s 299us/step - loss: 0.3932
# Epoch 24/50
# 2541/2541 [==============================] - 1s 313us/step - loss: 0.3940
# Epoch 25/50
# 2541/2541 [==============================] - 1s 309us/step - loss: 0.3992
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 26/50
# 2541/2541 [==============================] - 1s 312us/step - loss: 0.3942
# Epoch 27/50
# 2541/2541 [==============================] - 1s 314us/step - loss: 0.3876
# Epoch 28/50
# 2541/2541 [==============================] - 1s 299us/step - loss: 0.3771
# Epoch 29/50
# 2541/2541 [==============================] - 1s 313us/step - loss: 0.3735
# Epoch 30/50
# 2541/2541 [==============================] - 1s 307us/step - loss: 0.3794
# Epoch 31/50
# 2541/2541 [==============================] - 1s 307us/step - loss: 0.3711
# Epoch 32/50
# 2541/2541 [==============================] - 1s 314us/step - loss: 0.3687
# Epoch 33/50
# 2541/2541 [==============================] - 1s 300us/step - loss: 0.3632
# Epoch 34/50
# 2541/2541 [==============================] - 1s 314us/step - loss: 0.3651
# Epoch 35/50
# 2541/2541 [==============================] - 1s 310us/step - loss: 0.3641
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 36/50
# 2541/2541 [==============================] - 1s 307us/step - loss: 0.3514
# Epoch 37/50
# 2541/2541 [==============================] - 1s 312us/step - loss: 0.3621
# Epoch 38/50
# 2541/2541 [==============================] - 1s 302us/step - loss: 0.3601
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 39/50
# 2541/2541 [==============================] - 1s 313us/step - loss: 0.3418
# Epoch 40/50
# 2541/2541 [==============================] - 1s 312us/step - loss: 0.3470
# Epoch 41/50
# 2541/2541 [==============================] - 1s 300us/step - loss: 0.3446
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 42/50
# 2541/2541 [==============================] - 1s 316us/step - loss: 0.3511
# Epoch 43/50
# 2541/2541 [==============================] - 1s 301us/step - loss: 0.3542
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 44/50
# 2541/2541 [==============================] - 1s 470us/step - loss: 0.3473
# Epoch 45/50
# 2541/2541 [==============================] - 4s 2ms/step - loss: 0.3456
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 46/50
# 2541/2541 [==============================] - 1s 302us/step - loss: 0.3402
# Epoch 47/50
# 2541/2541 [==============================] - 1s 313us/step - loss: 0.3425
# Epoch 48/50
# 2541/2541 [==============================] - 1s 302us/step - loss: 0.3539
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 49/50
# 2541/2541 [==============================] - 1s 313us/step - loss: 0.3435
# Epoch 50/50
# 2541/2541 [==============================] - 1s 315us/step - loss: 0.3490
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.

# %%
val = df.loc[train_val_folds[0][1]]
val_atoms, val_bonds, val_edges = dataframe_to_gcn_input(val["rdkit"])

# %%
embeddings_val = gcn_model.predict([val_atoms, val_bonds, val_edges])
df_embeddings = pd.DataFrame(embeddings_val)
#df_embeddings.to_csv("/Users/tomas/Desktop/binding/p38_splits/embeddings_new_splits/fold_0/embeddings_val.csv")
#val.to_csv("/Users/tomas/Desktop/binding/p38_splits/embeddings_new_splits/fold_0/val_0.csv")
embeddings_train = gcn_model.predict([train_atoms, train_bonds, train_edges])
df_embeddings_train = pd.DataFrame(embeddings_train)
#df_embeddings_train.to_csv("/Users/tomas/Desktop/binding/p38_splits/embeddings_new_splits/fold_0/embeddings_train.csv")
#train.to_csv("/Users/tomas/Desktop/binding/p38_splits/embeddings_new_splits/fold_0/train_0.csv")

# %%
from numba import cuda 
device = cuda.get_current_device()
device.reset()

# %%
def calculate_metrics(y_true, y_pred, plots=False):
    assert isinstance(y_true, np.ndarray), 'y_true should be np.array'
    assert len(y_true.shape) == len(y_pred.shape) == 1, 'y_true or y_pred shapes are not 1 (probably not squeezed)'
    y_pred_bin = y_pred > 0.5

    cf = confusion_matrix(y_true, y_pred_bin)
    tn, fp, fn, tp = cf.ravel()

    metrics = {
        'roc_auc': roc_auc_score(y_true, y_pred),
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'tp': tp,
        'map': average_precision_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred_bin),
        'recall': recall_score(y_true, y_pred_bin),
        'accuracy': accuracy_score(y_true, y_pred_bin),
    }

    if plots:
        print('predictions histogram')
        plt.figure()
        plt.hist(y_pred, bins=int(len(y_pred) / 3))
        plt.show()

        print('confusion matrix')
        plt.figure()
        group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
        group_counts = ['{0:0.0f}'.format(value) for value in
                        cf.flatten()]
        group_percentages = ['{0:.2%}'.format(value) for value in
                             cf.flatten() / np.sum(cf)]
        labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
                  zip(group_names, group_counts, group_percentages)]
        labels = np.asarray(labels).reshape(2, 2)
        sns.heatmap(cf, annot=labels, fmt='', cmap='Blues')
        plt.show()

        print('roc curve')
        random_probs = [0 for _ in range(len(y_true))]
        auc = roc_auc_score(y_true, y_pred)
        print('Logistic: ROC AUC=%.3f' % (auc))
        ns_fpr, ns_tpr, _ = roc_curve(y_true, random_probs)
        lr_fpr, lr_tpr, _ = roc_curve(y_true, y_pred)
        plt.plot(ns_fpr, ns_tpr, linestyle='--', label='random')
        plt.plot(lr_fpr, lr_tpr, marker='.')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend()
        plt.show()

    return metrics

# %%
hyper_params = {
        "colsample_bylevel" : 0.8252200966638428,
        "colsample_bytree" : 0.6160,
        "gamma" : 0.2070,
        "eta" : 0.5903,
        "max_delta_step" : 3,
        "max_depth" : 8,
        "min_child_weight" : 70,
        "alpha" : 21.24299,
        "lambda" : 38.191928,
        "subsample" : 0.87876195660726,
        "eval_metric":'auc',
        "objective":'binary:logistic',
        "booster":'gbtree',
        "tree_method" : 'gpu_hist',
        "single_precision_histogram" : True
}

# %%
import xgboost as xgb

# %%
labels_binary = train.Binary
labels_val = val.Binary

# %%
dmatrix_train = xgb.DMatrix(data = embeddings_train,label = labels_binary)
dmatrix_val = xgb.DMatrix(data = embeddings_val,label = labels_val)

# %%
evalist = [(dmatrix_val,'eval'),(dmatrix_train,'train')]

# %%
model = xgb.train(hyper_params,dmatrix_train,300,evalist,verbose_eval=True)
# Out:
# [0]	eval-auc:0.81735	train-auc:0.92948
# [1]	eval-auc:0.85812	train-auc:0.94787
# [2]	eval-auc:0.86820	train-auc:0.95758
# [3]	eval-auc:0.86989	train-auc:0.96225
# [4]	eval-auc:0.87336	train-auc:0.96654
# [5]	eval-auc:0.88604	train-auc:0.96874
# [6]	eval-auc:0.88710	train-auc:0.96971
# [7]	eval-auc:0.88678	train-auc:0.96962
# [8]	eval-auc:0.88642	train-auc:0.96982
# [9]	eval-auc:0.88723	train-auc:0.97005
# [10]	eval-auc:0.88775	train-auc:0.97077
# [11]	eval-auc:0.88763	train-auc:0.97093
# [12]	eval-auc:0.88787	train-auc:0.97094
# [13]	eval-auc:0.88917	train-auc:0.97093
# [14]	eval-auc:0.88872	train-auc:0.97086
# [15]	eval-auc:0.88772	train-auc:0.97074
# [16]	eval-auc:0.88787	train-auc:0.97078
# [17]	eval-auc:0.88915	train-auc:0.97092
# [18]	eval-auc:0.88869	train-auc:0.97091
# [19]	eval-auc:0.88870	train-auc:0.97111
# [20]	eval-auc:0.88865	train-auc:0.97119
# [21]	eval-auc:0.88846	train-auc:0.97119
# [22]	eval-auc:0.88896	train-auc:0.97191
# [23]	eval-auc:0.88910	train-auc:0.97195
# [24]	eval-auc:0.88910	train-auc:0.97195
# [25]	eval-auc:0.88867	train-auc:0.97199
# [26]	eval-auc:0.88864	train-auc:0.97200
# [27]	eval-auc:0.88872	train-auc:0.97204
# [28]	eval-auc:0.88868	train-auc:0.97213
# [29]	eval-auc:0.88868	train-auc:0.97213
# [30]	eval-auc:0.88868	train-auc:0.97213
# [31]	eval-auc:0.88901	train-auc:0.97218
# [32]	eval-auc:0.88901	train-auc:0.97218
# [33]	eval-auc:0.88901	train-auc:0.97218
# [34]	eval-auc:0.88901	train-auc:0.97218
# [35]	eval-auc:0.88901	train-auc:0.97218
# [36]	eval-auc:0.88894	train-auc:0.97218
# [37]	eval-auc:0.88894	train-auc:0.97218
# [38]	eval-auc:0.88911	train-auc:0.97218
# [39]	eval-auc:0.88911	train-auc:0.97218
# [40]	eval-auc:0.88911	train-auc:0.97218
# [41]	eval-auc:0.88911	train-auc:0.97218
# [42]	eval-auc:0.88911	train-auc:0.97218
# [43]	eval-auc:0.88911	train-auc:0.97218
# [44]	eval-auc:0.88849	train-auc:0.97213
# [45]	eval-auc:0.88846	train-auc:0.97213
# [46]	eval-auc:0.88782	train-auc:0.97217
# [47]	eval-auc:0.88841	train-auc:0.97228
# [48]	eval-auc:0.88819	train-auc:0.97228
# [49]	eval-auc:0.88819	train-auc:0.97228
# [50]	eval-auc:0.88831	train-auc:0.97239
# [51]	eval-auc:0.88831	train-auc:0.97239
# [52]	eval-auc:0.88831	train-auc:0.97239
# [53]	eval-auc:0.88831	train-auc:0.97239
# [54]	eval-auc:0.88832	train-auc:0.97240
# [55]	eval-auc:0.88835	train-auc:0.97246
# [56]	eval-auc:0.88835	train-auc:0.97246
# [57]	eval-auc:0.88835	train-auc:0.97246
# [58]	eval-auc:0.88835	train-auc:0.97246
# [59]	eval-auc:0.88835	train-auc:0.97246
# [60]	eval-auc:0.88835	train-auc:0.97246
# [61]	eval-auc:0.88835	train-auc:0.97246
# [62]	eval-auc:0.88835	train-auc:0.97246
# [63]	eval-auc:0.88835	train-auc:0.97246
# [64]	eval-auc:0.88835	train-auc:0.97247
# [65]	eval-auc:0.88835	train-auc:0.97247
# [66]	eval-auc:0.88835	train-auc:0.97247
# [67]	eval-auc:0.88835	train-auc:0.97247
# [68]	eval-auc:0.88842	train-auc:0.97251
# [69]	eval-auc:0.88842	train-auc:0.97251
# [70]	eval-auc:0.88842	train-auc:0.97251
# [71]	eval-auc:0.88842	train-auc:0.97251
# [72]	eval-auc:0.88852	train-auc:0.97251
# [73]	eval-auc:0.88852	train-auc:0.97251
# [74]	eval-auc:0.88852	train-auc:0.97251
# [75]	eval-auc:0.88927	train-auc:0.97245
# [76]	eval-auc:0.88927	train-auc:0.97245
# [77]	eval-auc:0.88927	train-auc:0.97245
# [78]	eval-auc:0.88927	train-auc:0.97245
# [79]	eval-auc:0.88927	train-auc:0.97245
# [80]	eval-auc:0.88927	train-auc:0.97245
# [81]	eval-auc:0.88927	train-auc:0.97245
# [82]	eval-auc:0.88927	train-auc:0.97245
# [83]	eval-auc:0.88898	train-auc:0.97272
# [84]	eval-auc:0.88898	train-auc:0.97272
# [85]	eval-auc:0.88898	train-auc:0.97272
# [86]	eval-auc:0.88898	train-auc:0.97272
# [87]	eval-auc:0.88898	train-auc:0.97272
# [88]	eval-auc:0.88898	train-auc:0.97272
# [89]	eval-auc:0.88898	train-auc:0.97272
# [90]	eval-auc:0.88898	train-auc:0.97272
# [91]	eval-auc:0.88898	train-auc:0.97272
# [92]	eval-auc:0.88897	train-auc:0.97273
# [93]	eval-auc:0.88897	train-auc:0.97273
# [94]	eval-auc:0.88897	train-auc:0.97273
# [95]	eval-auc:0.88887	train-auc:0.97274
# [96]	eval-auc:0.88883	train-auc:0.97276
# [97]	eval-auc:0.88883	train-auc:0.97276
# [98]	eval-auc:0.88883	train-auc:0.97276
# [99]	eval-auc:0.88883	train-auc:0.97276
# [100]	eval-auc:0.88883	train-auc:0.97276
# [101]	eval-auc:0.88883	train-auc:0.97276
# [102]	eval-auc:0.88883	train-auc:0.97276
# [103]	eval-auc:0.88883	train-auc:0.97276
# [104]	eval-auc:0.88883	train-auc:0.97276
# [105]	eval-auc:0.88883	train-auc:0.97276
# [106]	eval-auc:0.88883	train-auc:0.97276
# [107]	eval-auc:0.88883	train-auc:0.97276
# [108]	eval-auc:0.88883	train-auc:0.97276
# [109]	eval-auc:0.88883	train-auc:0.97276
# [110]	eval-auc:0.88883	train-auc:0.97276
# [111]	eval-auc:0.88883	train-auc:0.97276
# [112]	eval-auc:0.88883	train-auc:0.97276
# [113]	eval-auc:0.88883	train-auc:0.97276
# [114]	eval-auc:0.88883	train-auc:0.97276
# [115]	eval-auc:0.88883	train-auc:0.97276
# [116]	eval-auc:0.88865	train-auc:0.97273
# [117]	eval-auc:0.88865	train-auc:0.97273
# [118]	eval-auc:0.88865	train-auc:0.97273
# [119]	eval-auc:0.88865	train-auc:0.97273
# [120]	eval-auc:0.88865	train-auc:0.97273
# [121]	eval-auc:0.88865	train-auc:0.97273
# [122]	eval-auc:0.88865	train-auc:0.97273
# [123]	eval-auc:0.88865	train-auc:0.97273
# [124]	eval-auc:0.88865	train-auc:0.97273
# [125]	eval-auc:0.88865	train-auc:0.97273
# [126]	eval-auc:0.88885	train-auc:0.97273
# [127]	eval-auc:0.88885	train-auc:0.97273
# [128]	eval-auc:0.88885	train-auc:0.97273
# [129]	eval-auc:0.88885	train-auc:0.97273
# [130]	eval-auc:0.88885	train-auc:0.97273
# [131]	eval-auc:0.88885	train-auc:0.97273
# [132]	eval-auc:0.88885	train-auc:0.97273
# [133]	eval-auc:0.88885	train-auc:0.97273
# [134]	eval-auc:0.88885	train-auc:0.97273
# [135]	eval-auc:0.88885	train-auc:0.97273
# [136]	eval-auc:0.88885	train-auc:0.97273
# [137]	eval-auc:0.88868	train-auc:0.97273
# [138]	eval-auc:0.88868	train-auc:0.97273
# [139]	eval-auc:0.88868	train-auc:0.97273
# [140]	eval-auc:0.88868	train-auc:0.97273
# [141]	eval-auc:0.88868	train-auc:0.97273
# [142]	eval-auc:0.88868	train-auc:0.97273
# [143]	eval-auc:0.88868	train-auc:0.97273
# [144]	eval-auc:0.88868	train-auc:0.97273
# [145]	eval-auc:0.88868	train-auc:0.97273
# [146]	eval-auc:0.88868	train-auc:0.97273
# [147]	eval-auc:0.88868	train-auc:0.97273
# [148]	eval-auc:0.88858	train-auc:0.97272
# [149]	eval-auc:0.88858	train-auc:0.97272
# [150]	eval-auc:0.88880	train-auc:0.97274
# [151]	eval-auc:0.88880	train-auc:0.97274
# [152]	eval-auc:0.88880	train-auc:0.97274
# [153]	eval-auc:0.88880	train-auc:0.97274
# [154]	eval-auc:0.88880	train-auc:0.97274
# [155]	eval-auc:0.88880	train-auc:0.97274
# [156]	eval-auc:0.88880	train-auc:0.97274
# [157]	eval-auc:0.88880	train-auc:0.97274
# [158]	eval-auc:0.88880	train-auc:0.97274
# [159]	eval-auc:0.88880	train-auc:0.97274
# [160]	eval-auc:0.88880	train-auc:0.97274
# [161]	eval-auc:0.88880	train-auc:0.97274
# [162]	eval-auc:0.88880	train-auc:0.97274
# [163]	eval-auc:0.88863	train-auc:0.97277
# [164]	eval-auc:0.88863	train-auc:0.97277
# [165]	eval-auc:0.88863	train-auc:0.97277
# [166]	eval-auc:0.88863	train-auc:0.97277
# [167]	eval-auc:0.88863	train-auc:0.97277
# [168]	eval-auc:0.88863	train-auc:0.97277
# [169]	eval-auc:0.88863	train-auc:0.97277
# [170]	eval-auc:0.88863	train-auc:0.97277
# [171]	eval-auc:0.88863	train-auc:0.97277
# [172]	eval-auc:0.88863	train-auc:0.97277
# [173]	eval-auc:0.88863	train-auc:0.97277
# [174]	eval-auc:0.88863	train-auc:0.97277
# [175]	eval-auc:0.88863	train-auc:0.97277
# [176]	eval-auc:0.88863	train-auc:0.97277
# [177]	eval-auc:0.88863	train-auc:0.97277
# [178]	eval-auc:0.88863	train-auc:0.97277
# [179]	eval-auc:0.88863	train-auc:0.97277
# [180]	eval-auc:0.88863	train-auc:0.97277
# [181]	eval-auc:0.88863	train-auc:0.97277
# [182]	eval-auc:0.88863	train-auc:0.97277
# [183]	eval-auc:0.88863	train-auc:0.97277
# [184]	eval-auc:0.88863	train-auc:0.97277
# [185]	eval-auc:0.88863	train-auc:0.97277
# [186]	eval-auc:0.88863	train-auc:0.97277
# [187]	eval-auc:0.88863	train-auc:0.97277
# [188]	eval-auc:0.88863	train-auc:0.97277
# [189]	eval-auc:0.88863	train-auc:0.97277
# [190]	eval-auc:0.88863	train-auc:0.97277
# [191]	eval-auc:0.88863	train-auc:0.97277
# [192]	eval-auc:0.88863	train-auc:0.97277
# [193]	eval-auc:0.88863	train-auc:0.97277
# [194]	eval-auc:0.88863	train-auc:0.97277
# [195]	eval-auc:0.88863	train-auc:0.97277
# [196]	eval-auc:0.88863	train-auc:0.97277
# [197]	eval-auc:0.88863	train-auc:0.97277
# [198]	eval-auc:0.88863	train-auc:0.97277
# [199]	eval-auc:0.88863	train-auc:0.97277
# [200]	eval-auc:0.88863	train-auc:0.97277
# [201]	eval-auc:0.88863	train-auc:0.97277
# [202]	eval-auc:0.88863	train-auc:0.97277
# [203]	eval-auc:0.88863	train-auc:0.97277
# [204]	eval-auc:0.88863	train-auc:0.97277
# [205]	eval-auc:0.88863	train-auc:0.97277
# [206]	eval-auc:0.88863	train-auc:0.97277
# [207]	eval-auc:0.88863	train-auc:0.97277
# [208]	eval-auc:0.88863	train-auc:0.97277
# [209]	eval-auc:0.88880	train-auc:0.97280
# [210]	eval-auc:0.88880	train-auc:0.97280
# [211]	eval-auc:0.88880	train-auc:0.97280
# [212]	eval-auc:0.88880	train-auc:0.97280
# [213]	eval-auc:0.88880	train-auc:0.97280
# [214]	eval-auc:0.88880	train-auc:0.97280
# [215]	eval-auc:0.88880	train-auc:0.97280
# [216]	eval-auc:0.88880	train-auc:0.97280
# [217]	eval-auc:0.88880	train-auc:0.97280
# [218]	eval-auc:0.88880	train-auc:0.97280
# [219]	eval-auc:0.88880	train-auc:0.97280
# [220]	eval-auc:0.88880	train-auc:0.97280
# [221]	eval-auc:0.88880	train-auc:0.97280
# [222]	eval-auc:0.88880	train-auc:0.97280
# [223]	eval-auc:0.88880	train-auc:0.97280
# [224]	eval-auc:0.88880	train-auc:0.97280
# [225]	eval-auc:0.88880	train-auc:0.97280
# [226]	eval-auc:0.88880	train-auc:0.97280
# [227]	eval-auc:0.88880	train-auc:0.97280
# [228]	eval-auc:0.88880	train-auc:0.97280
# [229]	eval-auc:0.88880	train-auc:0.97280
# [230]	eval-auc:0.88880	train-auc:0.97280
# [231]	eval-auc:0.88880	train-auc:0.97280
# [232]	eval-auc:0.88872	train-auc:0.97283
# [233]	eval-auc:0.88900	train-auc:0.97284
# [234]	eval-auc:0.88900	train-auc:0.97284
# [235]	eval-auc:0.88900	train-auc:0.97284
# [236]	eval-auc:0.88900	train-auc:0.97284
# [237]	eval-auc:0.88900	train-auc:0.97284
# [238]	eval-auc:0.88900	train-auc:0.97284
# [239]	eval-auc:0.88900	train-auc:0.97284
# [240]	eval-auc:0.88900	train-auc:0.97284
# [241]	eval-auc:0.88880	train-auc:0.97289
# [242]	eval-auc:0.88880	train-auc:0.97289
# [243]	eval-auc:0.88880	train-auc:0.97289
# [244]	eval-auc:0.88880	train-auc:0.97289
# [245]	eval-auc:0.88880	train-auc:0.97289
# [246]	eval-auc:0.88880	train-auc:0.97289
# [247]	eval-auc:0.88880	train-auc:0.97289
# [248]	eval-auc:0.88880	train-auc:0.97289
# [249]	eval-auc:0.88880	train-auc:0.97289
# [250]	eval-auc:0.88904	train-auc:0.97291
# [251]	eval-auc:0.88904	train-auc:0.97291
# [252]	eval-auc:0.88904	train-auc:0.97291
# [253]	eval-auc:0.88904	train-auc:0.97291
# [254]	eval-auc:0.88904	train-auc:0.97291
# [255]	eval-auc:0.88904	train-auc:0.97291
# [256]	eval-auc:0.88904	train-auc:0.97291
# [257]	eval-auc:0.88904	train-auc:0.97291
# [258]	eval-auc:0.88904	train-auc:0.97291
# [259]	eval-auc:0.88904	train-auc:0.97291
# [260]	eval-auc:0.88904	train-auc:0.97291
# [261]	eval-auc:0.88904	train-auc:0.97291
# [262]	eval-auc:0.88904	train-auc:0.97291
# [263]	eval-auc:0.88904	train-auc:0.97291
# [264]	eval-auc:0.88904	train-auc:0.97291
# [265]	eval-auc:0.88904	train-auc:0.97291
# [266]	eval-auc:0.88904	train-auc:0.97291
# [267]	eval-auc:0.88904	train-auc:0.97291
# [268]	eval-auc:0.88904	train-auc:0.97291
# [269]	eval-auc:0.88891	train-auc:0.97294
# [270]	eval-auc:0.88891	train-auc:0.97294
# [271]	eval-auc:0.88891	train-auc:0.97294
# [272]	eval-auc:0.88891	train-auc:0.97294
# [273]	eval-auc:0.88891	train-auc:0.97294
# [274]	eval-auc:0.88891	train-auc:0.97294
# [275]	eval-auc:0.88891	train-auc:0.97294
# [276]	eval-auc:0.88891	train-auc:0.97294
# [277]	eval-auc:0.88891	train-auc:0.97294
# [278]	eval-auc:0.88891	train-auc:0.97294
# [279]	eval-auc:0.88891	train-auc:0.97294
# [280]	eval-auc:0.88891	train-auc:0.97294
# [281]	eval-auc:0.88891	train-auc:0.97294
# [282]	eval-auc:0.88891	train-auc:0.97294
# [283]	eval-auc:0.88891	train-auc:0.97294
# [284]	eval-auc:0.88891	train-auc:0.97294
# [285]	eval-auc:0.88891	train-auc:0.97294
# [286]	eval-auc:0.88891	train-auc:0.97294
# [287]	eval-auc:0.88891	train-auc:0.97294
# [288]	eval-auc:0.88882	train-auc:0.97293
# [289]	eval-auc:0.88882	train-auc:0.97293
# [290]	eval-auc:0.88882	train-auc:0.97293
# [291]	eval-auc:0.88882	train-auc:0.97293
# [292]	eval-auc:0.88882	train-auc:0.97293
# [293]	eval-auc:0.88882	train-auc:0.97293
# [294]	eval-auc:0.88882	train-auc:0.97293
# [295]	eval-auc:0.88897	train-auc:0.97294
# [296]	eval-auc:0.88897	train-auc:0.97294
# [297]	eval-auc:0.88899	train-auc:0.97296
# [298]	eval-auc:0.88899	train-auc:0.97296
# [299]	eval-auc:0.88899	train-auc:0.97296

# %%
y_pred_val = model.predict(dmatrix_val)
y_pred_train = model.predict(dmatrix_train)

# %%
validation_metrics= calculate_metrics(np.array(labels_val),y_pred_val)
training_metrics = calculate_metrics(np.array(labels_binary),y_pred_train)

# %%
validation_metrics
# Out:
# {'roc_auc': 0.8889889734430811,
#  'tn': 230,
#  'fp': 44,
#  'fn': 54,
#  'tp': 181,
#  'map': 0.8742267186605603,
#  'precision': 0.8044444444444444,
#  'recall': 0.7702127659574468,
#  'accuracy': 0.8074656188605108}

# %%
training_metrics
# Out:
# {'roc_auc': 0.9729591722913935,
#  'tn': 1163,
#  'fp': 129,
#  'fn': 90,
#  'tp': 1159,
#  'map': 0.9697000745281956,
#  'precision': 0.8998447204968945,
#  'recall': 0.9279423538831065,
#  'accuracy': 0.9138134592680047}
